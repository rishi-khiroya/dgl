# %% [markdown]
# # Question 2: Node Classification in a Heterogeneous Graph
#
# In this question, you will explore node classifcation using GNNs in a heterogeneous graph with two types of nodes containing different number of features.

# %% [markdown]
# ## Setting a Seed for Reproducibility
#
# To ensure that our results are reproducible, we will set a fixed seed for the random number generator. This step is crucial for educational and testing purposes, as it allows the same random numbers to be generated each time the notebook is run.

# %%
import numpy as np
import torch
import torch.nn as nn
import torch.nn.functional as F
import random
from scipy.stats import norm
import matplotlib.pyplot as plt
import json
import torch.optim as optim
import copy
from torch.nn.functional import binary_cross_entropy
from sklearn.metrics import precision_recall_fscore_support
from torch.optim import lr_scheduler
import networkx as nx

SEED = 42
TRAIN_PATH = "data/q2_train.json"
VAL_PATH = "data/q2_val.json"

def set_seed(seed=42):
    random.seed(seed)
    np.random.seed(seed)
    torch.manual_seed(seed)
    if torch.cuda.is_available():
        torch.cuda.manual_seed_all(seed)

    torch.backends.cudnn.deterministic = True
    torch.backends.cudnn.benchmark = False
    

set_seed(SEED)

# %% [markdown]
# ## Question 2.1 Dataset
#
# The heterogeneous graph $G=(V,E)$ consists of a set of nodes $V$ with two types of nodes:
# - **Type 1 nodes**: Feature dimension of $d_1 = 20$
# - **Type 2 nodes**: Feature dimension of $d_2 = 30$
#
# Each node belongs to one of two classes:
#   - **Class 0**: $y_i = 0$
#   - **Class 1**: $y_i = 1$
#
# In total, there are $N=N_1 + N_2$ nodes in the graph.
#
# In the following cell, we load the data from the given **JSON** file.

# %%
def load_data_from_json(json_path):
    """
    Loads a JSON describing a heterogeneous graph

    Returns:
      A : torch.FloatTensor, shape (N, N)
          Adjacency matrix for all nodes (0...N-1).
      X1 : torch.FloatTensor, shape (N1, d1)
      X2 : torch.FloatTensor, shape (N2, d2)
      y : torch.LongTensor, shape (N,)
          Labels for each node (0 or 1 for binary).
      mapping : dict
          mapping[i] = {
             "node_type": str ("type1" or "type2"),
             "feat_index": int index into the relevant feature array
          }
        This tells us how adjacency row i corresponds to a row in either type1_features or type2_features.
    """
    with open(json_path, "r") as f:
        data = json.load(f)

    nodes_info = data["nodes"]
    # Sort so adjacency row i matches global_index = i
    nodes_info.sort(key=lambda x: x["global_index"])

    N = len(nodes_info)
    A = torch.zeros((N, N), dtype=torch.float)

    # We'll store raw lists for type1 and type2, then convert to tensors
    type1_list = []
    type2_list = []
    # We'll also store the mapping from adjacency index -> (type, index_in_that_type)
    mapping = {}
    # We'll store labels in a list
    labels_list = []

    # Step 1: first pass to build adjacency
    #         (we'll also note how many type1 vs type2)
    for i, node in enumerate(nodes_info):
        for nbr_idx in node["connected_nodes"]:
            A[i, nbr_idx] = 1.0
            A[nbr_idx, i] = 1.0  # undirected

    # Step 2: second pass, fill feature arrays, mapping
    type1_count = 0
    type2_count = 0

    for i, node in enumerate(nodes_info):
        node_type = node["node_type"]
        feats = node["features"]
        label = node["label"] if node["label"] is not None else 0
        labels_list.append(label)

        if node_type == "type1":
            type1_list.append(feats)
            mapping[i] = {"node_type": "type1", "feat_index": type1_count}
            type1_count += 1
        else:
            type2_list.append(feats)
            mapping[i] = {"node_type": "type2", "feat_index": type2_count}
            type2_count += 1

    # Convert type1 and type2 lists into float tensors
    X1 = torch.tensor(type1_list, dtype=torch.float) if len(type1_list) else torch.empty((0,0))
    X2 = torch.tensor(type2_list, dtype=torch.float) if len(type2_list) else torch.empty((0,0))

    # Convert labels
    y = torch.tensor(labels_list, dtype=torch.long)  # shape (N,)

    return A, X1, X2, y, mapping

# %% [markdown]
# In the following cell, we load the **train** and **validation** datasets.

# %%
A_train, X1_train, X2_train, y_train, mapping_train = load_data_from_json(TRAIN_PATH)
A_val,   X1_val,   X2_val,   y_val,   mapping_val   = load_data_from_json(VAL_PATH)

# %% [markdown]
# ## Question 2.1 Interpretation of the Dataset
#
# Before diving into the modeling phase, it's crucial to explore and understand the data. Immplement the following functions to assist in this analysis:
#
#
# ### Question 2.1.c `plot_graph`
# - Implement the `plot_graph` function which visualizes the graph structure.
# - Color nodes by class labels and display their types.

# %%
# ####################################################
# MODIFY THE CODE BELOW 
# ####################################################


def plot_graph(A, y, mapping):
    """
    Visualize the graph structure with:
      - node colors based on their labels
      - node types written over the nodes
    """

    y = y.numpy() if isinstance(y, torch.Tensor) else np.array(y)

    # Create a NetworkX graph from the adjacency matrix
    G = nx.from_numpy_array(A.numpy())

    # Assign positions to nodes
    pos = nx.spring_layout(G)

    # Assign colors based on labels
    labels = np.unique(y)
    cmap = plt.cm.get_cmap("coolwarm", len(labels))  # Use a diverging colormap
    color_map = {label: cmap(i) for i, label in enumerate(labels)}
    node_colors = [color_map[label] for label in y]

    # Plot the graph
    plt.figure(figsize=(8, 6))
    nx.draw(G, pos, node_color=node_colors, with_labels=False, edge_color="gray", node_size=500, cmap=cmap)

    # Annotate nodes with their types
    for i, (x, y_pos) in enumerate(pos.values()):
        node_type = mapping[i]["node_type"]
        plt.text(x, y_pos, node_type, fontsize=9, ha="center", va="center", color="black")

    plt.show()

# ####################################################
# END OF MODIFICATION
# ####################################################

# %% [markdown]
# ### Question 2.1.d `plot_node_feature_distributions`
# Implement the `plot_node_feature_distributions` function.
#
# - This function should plot the distribution of the node features.
# - Do not consider the distribution of a specific feature $x_i$; instead, consider the mean of the feature vector $\mathbf{x}$ for each node.
# - All distributions should appear on the **same figure**, so you can compare the feature distributions of $t_1$ and $t_2$ nodes as well as $c_1$ and $c_2$ nodes in Question 2.1.e
# - Check Figure 1 in the Coursework Description PDF for reference on how your plot should look.
#
#
# **NOTE:** The questions above are named as Question 2.1.c and Question 2.1.d by purpose to be consistent with the Coursework Description PDF, the other subquestions of Question 2 need to be answered in your report.

# %%
# ####################################################
# MODIFY THE CODE BELOW 
# ####################################################

def plot_node_feature_distributions(X1, X2, y, mapping):
    """
    Plots the distributions (as normal PDFs) of the *average* feature values
    for four groups of nodes on the *same* figure:
      * type1, class=1
      * type1, class=2
      * type2, class=1
      * type2, class=2
    """
    
    X1 = X1.numpy()
    X2 = X2.numpy()
    y = y.numpy()

    # Initialize groups
    groups = {
        "Type 1, Class 1": [],
        "Type 1, Class 2": [],
        "Type 2, Class 1": [],
        "Type 2, Class 2": []
    }

    # Compute mean feature values per node
    for i, label in enumerate(y):
        node_info = mapping[i]
        node_type = node_info["node_type"]
        feat_index = node_info["feat_index"]

        if node_type == "type1" and len(X1) > 0:
            avg_feature = np.mean(X1[feat_index])
            if label == 1:
                groups["Type 1, Class 1"].append(avg_feature)
            else:
                groups["Type 1, Class 2"].append(avg_feature)
        
        elif node_type == "type2" and len(X2) > 0:
            avg_feature = np.mean(X2[feat_index])
            if label == 1:
                groups["Type 2, Class 1"].append(avg_feature)
            else:
                groups["Type 2, Class 2"].append(avg_feature)

    # Plot distributions
    plt.figure(figsize=(8, 6))

    all_vals = []
    for _, vals in groups.items():
        all_vals += vals
    
    x_min = min(all_vals)
    x_max = max(all_vals)
    padding = 0.1 * (x_max - x_min)
    x_range = np.linspace(x_min - padding, x_max + padding, 200)  

    for group_name, values in groups.items():
        if len(values) > 1:  # Ensure enough points to compute distribution
            mu, sigma = np.mean(values), np.std(values)
            plt.plot(x_range, norm.pdf(x_range, mu, sigma), label=f"{group_name} (μ={mu:.2f}, σ={sigma:.2f})")


    plt.xlabel("Average Feature Value")
    plt.ylabel("Density")
    plt.title("Node Feature Distributions by Type and Class")
    plt.legend()
    plt.grid(True)
    plt.show()

# ####################################################
# END OF MODIFICATION
# ####################################################

# %% [markdown]
# Call your functions...

# %%
# ####################################################
# MODIFY THE CODE BELOW 
# ####################################################

plot_graph(A_train, y_train, mapping_train)
plot_graph(A_val, y_val, mapping_val)

# ####################################################
# END OF MODIFICATION
# ####################################################
# Out:
# /tmp/ipykernel_1635939/1852137938.py:23: MatplotlibDeprecationWarning: The get_cmap function was deprecated in Matplotlib 3.7 and will be removed in 3.11. Use ``matplotlib.colormaps[name]`` or ``matplotlib.colormaps.get_cmap()`` or ``pyplot.get_cmap()`` instead.
#   cmap = plt.cm.get_cmap("coolwarm", len(labels))  # Use a diverging colormap
# /vol/bitbucket/rk1121/dgl/.venv/lib/python3.12/site-packages/networkx/drawing/nx_pylab.py:457: UserWarning: No data for colormapping provided via 'c'. Parameters 'cmap' will be ignored
#   node_collection = ax.scatter(

# %%
# ####################################################
# MODIFY THE CODE BELOW 
# ####################################################

plot_node_feature_distributions(X1_train, X2_train, y_train, mapping_train)
plot_node_feature_distributions(X1_val, X2_val, y_val, mapping_val)

# ####################################################
# END OF MODIFICATION
# ####################################################

# %% [markdown]
# ## Question 2.2 Naive Solution
#
# Nothing to implement in Question 2.2 :)
#
# In the naive solution, we handle the challenge of heterogeneous node feature dimensions by zero-padding all node feature vectors to match the maximum dimension. This ensures uniformity in the input dimensions for the Graph Convolutional Network (GCN).
#
# ### Zero Padding
# Let the feature dimension of a node $i$ be $d_i$. To create uniform dimensions:
#
# $$
# \mathbf{x}_i^{\text{padded}} = \begin{bmatrix}
# \mathbf{x}_i \\
# \mathbf{0}
# \end{bmatrix},
# $$
#
# where $ \mathbf{x}_i \in \mathbb{R}^{d_i} $ is the original feature vector, and the padding $ \mathbf{0} $ is of size $ d_{\text{max}} - d_i $. Here, $ d_{\text{max}} = \max\{d_i \mid i \in \text{nodes}\} $.

# %%
def pad_features(A, type1_features, type2_features, mapping):
    """
    Given:
      A : (N, N) adjacency
      type1_features : (num_type1, d1)
      type2_features : (num_type2, d2)
      mapping : a dict so that mapping[i] = {"node_type": "type1" or "type2",
                                             "feat_index": index in that type's feature array}

    Produces:
      X : torch.FloatTensor, shape (N, d_max)
        Where d_max = max(d1, d2).
        For each node i, we copy either type1_features or type2_features 
        into row i, zero-padding if needed.
      d_max : the dimension used for the padding.
    """
    device = A.device
    N = A.shape[0]

    # Determine the dimensions of type1 & type2
    d1 = type1_features.shape[1] if type1_features.ndim == 2 and type1_features.shape[0] > 0 else 0
    d2 = type2_features.shape[1] if type2_features.ndim == 2 and type2_features.shape[0] > 0 else 0

    d_max = max(d1, d2)

    # Create a (N, d_max) zero tensor
    X = torch.zeros((N, d_max), dtype=torch.float, device=device)

    # Fill each row
    for i in range(N):
        node_type = mapping[i]["node_type"]
        feat_index = mapping[i]["feat_index"]
        if node_type == "type1":
            # If we have any type1 features at all
            if d1 > 0:
                X[i, :d1] = type1_features[feat_index].to(device)
        else:
            # type2
            if d2 > 0:
                X[i, :d2] = type2_features[feat_index].to(device)

    return X, d_max

# %% [markdown]
# ### Graph Convolutional Network (GCN)
#
# We are going to use a 2-layer GCN for the **binary node classification** task on the heterogeneous graph. Below, you can see the mathematical representation to generate predictions from GCN.
#
# The feature update rule for the next layer $ H_{k+1} $ in a graph convolutional network is given by the equation
#
# $$
# H_{k+1} = \sigma(\tilde{D}^{-1/2} \tilde{A} \tilde{D}^{-1/2} H_k \Omega_k + \Beta_k)
# $$
#
# where  $\tilde{D}$ is the degree matrix with added self-loops, $\tilde{A}$ is the adjacency matrix with self-loops, $H_k$ are the features from the previous layer, $ \Omega_k $ is the weight matrix at layer $ k $, $\Beta_k$ is the bias vector at layer $k$, and $\sigma $ denotes the activation function.

# %% [markdown]
# $\tilde{D}^{-1/2} \tilde{A} \tilde{D}^{-1/2}$ is the normalized adjacency matrix with self-loops. Below, you need to implement this normalization function.

# %%
def symmetric_normalize(A_tilde):
    """
    Performs symmetric normalization of A_tilde (Adj. matrix with self loops):
      A_norm = D^{-1/2} * A_tilde * D^{-1/2}
    Where D_{ii} = sum of row i in A_tilde.

    A_tilde (N, N): Adj. matrix with self loops
    Returns:
      A_norm : (N, N)
    """

    eps = 1e-5
    d = A_tilde.sum(dim=1) + eps
    D_inv = torch.diag(torch.pow(d, -0.5))
    return D_inv @ A_tilde @ D_inv

# %%
A_train_self_loops = A_train + torch.eye(A_train.size(0))
A_val_self_loops = A_val + torch.eye(A_val.size(0))

A_train_normalized = symmetric_normalize(A_train_self_loops)
A_val_normalized = symmetric_normalize(A_val_self_loops)

# %% [markdown]
# In the following cell, we define a simple 2-layer GCN model to use with our padded node features.

# %%
class GCNLayer(nn.Module):
    """
    A single layer of a Graph Convolutional Network (GCN).
    """
    def __init__(self, input_dim, output_dim, use_nonlinearity=True):
        super(GCNLayer, self).__init__()
        self.use_nonlinearity = use_nonlinearity
        self.Omega = nn.Parameter(torch.randn(input_dim, output_dim) * torch.sqrt(torch.tensor(2.0) / (input_dim + output_dim)))
        self.beta = nn.Parameter(torch.zeros(output_dim))

    def forward(self, H_k, A_normalized):
        agg = torch.matmul(A_normalized, H_k) # local agg
        H_k_next = torch.matmul(agg, self.Omega) + self.beta
        return F.relu(H_k_next) if self.use_nonlinearity else H_k_next

class GraphNeuralNetwork(nn.Module):
    """
    A simple Graph Neural Network model using two layers of Graph Convolutional Network (GCN)
    for binary classification. The sigmoid activation is applied in the output layer only if
    use_nonlinearity is set to True.
    """
    def __init__(self, input_dim, hidden_dim):
        super(GraphNeuralNetwork, self).__init__()

        # Define GCN layers
        self.gcn1 = GCNLayer(input_dim, hidden_dim, True)
        self.gcn2 = GCNLayer(hidden_dim, 1, False)

    def forward(self, A, X, **kwargs):
        # Pass through GCN layers
        H1 = self.gcn1(X, A)
        H2 = self.gcn2(H1, A)  # Output shape: (num_nodes, 1)

        output = torch.sigmoid(H2)  # Sigmoid activation per node
        if torch.isnan(output).any():
            output = torch.where(torch.isnan(output), torch.zeros_like(output), output)

        if kwargs.get("return_embeddings", None):
            return output, H1, H2
        else:
            return output

# %% [markdown]
# Please do not modify the following `train_model` and `evaluate_model` functions.

# %%
def get_lr(optimizer):
    for param_group in optimizer.param_groups:
        return param_group['lr']

def train_model(
    model,
    y_train,
    val_model_inputs,
    y_val,
    num_epochs=100,
    lr=0.01,
    validate_every=10,
    patience=10,
    **train_model_inputs
):
    """
    Train the model, validate every 'validate_every' epochs, and pick the 
    checkpoint with best validation accuracy.

    Parameters:
    -----------
    model : torch.nn.Module
        The PyTorch model to train.
    y_train : torch.Tensor
        Training labels (shape: (N,)).
    val_model_inputs : dict
        Dictionary of keyword arguments for the model's forward pass 
        for the validation set.
    y_val : torch.Tensor
        Validation labels (shape: (N_val,)).
    num_epochs : int
        Number of training epochs.
    lr : float
        Learning rate for the optimizer.
    validate_every : int
        Validate (and possibly checkpoint) every 'validate_every' epochs.
    **train_model_inputs :
        Keyword arguments for the model's forward pass for the training set.

    Returns:
    --------
    best_loss_history : list
        The training loss history across epochs.
    best_model_state_dict : dict
        The state dictionary of the model achieving the best validation accuracy.
    """

    model.train()
    optimizer = optim.AdamW(model.parameters(), lr=lr)
    scheduler = lr_scheduler.ReduceLROnPlateau(optimizer, mode="max", patience=patience)
    loss_history = []

    best_val_f1 = 0.0
    best_model_state_dict = None

    for epoch in range(num_epochs):
        model.train()

        optimizer.zero_grad()


        # Forward pass on training data
        out = model(**train_model_inputs)  # shape: (N, 1)
        out = out.squeeze(-1)  # shape: (N,)
        y_float = y_train.float()  # for BCE

        # Compute training loss
        loss = binary_cross_entropy(out, y_float)
        loss.backward()

        torch.nn.utils.clip_grad_norm_(model.parameters(), max_norm=1.0)

        optimizer.step()

        # Record training loss
        loss_value = loss.item()
        loss_history.append(loss_value)

        # Validation step
        if (epoch + 1) % validate_every == 0 or (epoch + 1) == num_epochs:
            val_prec, val_rec, val_f1, _ = evaluate_model(model, y_val, **val_model_inputs)
            scheduler.step(val_f1)
            
            lr = get_lr(optimizer)

            print(
                f"Epoch {epoch+1}/{num_epochs} - "
                f"Train Loss: {loss_value:.4f} - "
                f"Val Precision: {val_prec:.4f} - "
                f"Val Recall: {val_rec:.4f} - "
                f"Val F1: {val_f1:.4f} - "
                f"LR: {lr}"
            )
    
            # Check if this is the best f1 score so far
            if val_f1 > best_val_f1:
                best_val_f1 = val_f1
                best_model_state_dict = copy.deepcopy(model.state_dict())


            if lr < 1e-5:
                break

    
    # If we have a best model, load it
    if best_model_state_dict is not None:
        model.load_state_dict(best_model_state_dict)

    return loss_history, best_model_state_dict


@torch.no_grad()
def evaluate_model(model, y, **kwargs):
    """
    Runs forward pass, calculates binary predictions (threshold=0.5),
    and returns the accuracy score.
    """
    model.eval()
    out = model(**kwargs)  # shape: (N, 1)
    out = out.squeeze(-1)  # shape: (N,)
    preds = (out >= 0.5).long()

    y_true = y.cpu().numpy()
    y_pred = preds.cpu().numpy()

    return precision_recall_fscore_support(y_true, y_pred, average="micro")

# %% [markdown]
# Helper function to plot the history of loss during the training.

# %%
def plot_loss(loss_history, title):
    plt.figure()
    plt.plot(loss_history, label="loss")
    plt.xlabel("Epoch")
    plt.ylabel("Loss")
    plt.title(title)
    plt.legend()
    plt.show()

# %%
def plot_results(val_precs, val_recs, val_f1s, title_prefix='', figsize=(15,5)):
    """
    Plots three bar charts comparing precision, recall, and F1 scores 
    for multiple models on a single figure, each sorted by its own metric.
    The best model is always on the right for each plot.
    
    Args:
        val_precs (dict): Dictionary of model -> precision score
        val_recs (dict): Dictionary of model -> recall score
        val_f1s (dict): Dictionary of model -> F1 score
        title_prefix (str): Optional prefix for subplot titles
        figsize (tuple): Size of the overall figure
    """
    
    # Prepare the figure
    fig, axes = plt.subplots(nrows=1, ncols=3, figsize=figsize)
    
    # --- Sort and plot Precision ---
    # Sort by precision (ascending), so best is on the right
    sorted_precs = sorted(val_precs.items(), key=lambda x: x[1])
    prec_models = [x[0] for x in sorted_precs]  # model names
    prec_scores = [x[1] for x in sorted_precs]  # scores
    min_prec = min(prec_scores)
    
    axes[0].bar(prec_models, prec_scores, color='skyblue')
    # Start the y-axis a bit lower than the min value
    axes[0].set_ylim([
        min_prec - 0.05*(1 if min_prec == 0 else min_prec), 
        max(1.0, max(prec_scores))  # in case some scores > 1.0
    ])
    axes[0].set_title(f'{title_prefix}Precision', fontsize=12)
    axes[0].set_ylabel('Score')
    axes[0].set_xticks(range(len(prec_models)))
    axes[0].set_xticklabels(prec_models, rotation=45, ha='right')
    
    # --- Sort and plot Recall ---
    sorted_recs = sorted(val_recs.items(), key=lambda x: x[1])
    rec_models = [x[0] for x in sorted_recs]
    rec_scores = [x[1] for x in sorted_recs]
    min_recs = min(rec_scores)
    
    axes[1].bar(rec_models, rec_scores, color='salmon')
    axes[1].set_ylim([
        min_recs - 0.05*(1 if min_recs == 0 else min_recs),
        max(1.0, max(rec_scores))
    ])
    axes[1].set_title(f'{title_prefix}Recall', fontsize=12)
    axes[1].set_xticks(range(len(rec_models)))
    axes[1].set_xticklabels(rec_models, rotation=45, ha='right')
    
    # --- Sort and plot F1 ---
    sorted_f1s = sorted(val_f1s.items(), key=lambda x: x[1])
    f1_models = [x[0] for x in sorted_f1s]
    f1_scores = [x[1] for x in sorted_f1s]
    min_f1 = min(f1_scores)
    
    axes[2].bar(f1_models, f1_scores, color='limegreen')
    axes[2].set_ylim([
        min_f1 - 0.05*(1 if min_f1 == 0 else min_f1),
        max(1.0, max(f1_scores))
    ])
    axes[2].set_title(f'{title_prefix}F1', fontsize=12)
    axes[2].set_xticks(range(len(f1_models)))
    axes[2].set_xticklabels(f1_models, rotation=45, ha='right')
    
    plt.tight_layout()
    plt.show()

# %%
val_precs, val_recs, val_f1s = {}, {}, {}

# %% [markdown]
# Running the naive approach

# %%
set_seed(SEED)

# Naively pad
X_train, d_max_train = pad_features(A_train, X1_train, X2_train, mapping_train)
X_val,   d_max_val   = pad_features(A_val,   X1_val,   X2_val,   mapping_val)

print("Train adjacency:", A_train.shape)
print("Train features after padding:", X_train.shape, "with d_max =", d_max_train)
print("Val adjacency:", A_val.shape)
print("Val features after padding:", X_val.shape, "with d_max =", d_max_val)

# Convert labels to float if using BCE with sigmoid
y_train = y_train.float()  # shape (N,)
y_val   = y_val.float()

# Build the GCN model
input_dim = X_train.shape[1]  # the padded dimension
hidden_dim = 2
naive_gnn_model = GraphNeuralNetwork(input_dim, hidden_dim)

# Train
loss_history, _ = train_model(naive_gnn_model, y_train, val_model_inputs={"A":A_val_normalized.clone(), "X":X_val.clone()}, y_val=y_val.clone(), A=A_train_normalized, X=X_train, num_epochs=10000, lr=0.01, patience=50)

# Test on validation data
val_prec, val_rec, val_f1, _ = evaluate_model(naive_gnn_model, y_val, A=A_val_normalized, X=X_val)
print(f"[VAL] Prec={val_prec:.4f}, Rec={val_rec:.4f}, F1={val_f1:.4f}")

val_precs["Naive GCN"] = val_prec
val_recs["Naive GCN"] = val_rec
val_f1s["Naive GCN"] = val_f1

# Plot loss
plot_loss(loss_history, title="GCN Naive Approach Training Loss")
# Out:
# Train adjacency: torch.Size([500, 500])
# Train features after padding: torch.Size([500, 30]) with d_max = 30
# Val adjacency: torch.Size([200, 200])
# Val features after padding: torch.Size([200, 30]) with d_max = 30
# Epoch 10/10000 - Train Loss: 0.6906 - Val Precision: 0.5000 - Val Recall: 0.5000 - Val F1: 0.5000 - LR: 0.01
# Epoch 20/10000 - Train Loss: 0.6883 - Val Precision: 0.4900 - Val Recall: 0.4900 - Val F1: 0.4900 - LR: 0.01
# Epoch 30/10000 - Train Loss: 0.6868 - Val Precision: 0.4900 - Val Recall: 0.4900 - Val F1: 0.4900 - LR: 0.01
# Epoch 40/10000 - Train Loss: 0.6866 - Val Precision: 0.4900 - Val Recall: 0.4900 - Val F1: 0.4900 - LR: 0.01
# Epoch 50/10000 - Train Loss: 0.6863 - Val Precision: 0.4900 - Val Recall: 0.4900 - Val F1: 0.4900 - LR: 0.01
# Epoch 60/10000 - Train Loss: 0.6860 - Val Precision: 0.4900 - Val Recall: 0.4900 - Val F1: 0.4900 - LR: 0.01
# Epoch 70/10000 - Train Loss: 0.6856 - Val Precision: 0.4900 - Val Recall: 0.4900 - Val F1: 0.4900 - LR: 0.01
# Epoch 80/10000 - Train Loss: 0.6852 - Val Precision: 0.4900 - Val Recall: 0.4900 - Val F1: 0.4900 - LR: 0.01
# Epoch 90/10000 - Train Loss: 0.6848 - Val Precision: 0.4900 - Val Recall: 0.4900 - Val F1: 0.4900 - LR: 0.01
# Epoch 100/10000 - Train Loss: 0.6843 - Val Precision: 0.4900 - Val Recall: 0.4900 - Val F1: 0.4900 - LR: 0.01
# Epoch 110/10000 - Train Loss: 0.6838 - Val Precision: 0.4900 - Val Recall: 0.4900 - Val F1: 0.4900 - LR: 0.01
# Epoch 120/10000 - Train Loss: 0.6832 - Val Precision: 0.4900 - Val Recall: 0.4900 - Val F1: 0.4900 - LR: 0.01
# Epoch 130/10000 - Train Loss: 0.6825 - Val Precision: 0.4900 - Val Recall: 0.4900 - Val F1: 0.4900 - LR: 0.01
# Epoch 140/10000 - Train Loss: 0.6817 - Val Precision: 0.4900 - Val Recall: 0.4900 - Val F1: 0.4900 - LR: 0.01
# Epoch 150/10000 - Train Loss: 0.6808 - Val Precision: 0.4900 - Val Recall: 0.4900 - Val F1: 0.4900 - LR: 0.01
# Epoch 160/10000 - Train Loss: 0.6798 - Val Precision: 0.4900 - Val Recall: 0.4900 - Val F1: 0.4900 - LR: 0.01
# Epoch 170/10000 - Train Loss: 0.6786 - Val Precision: 0.4900 - Val Recall: 0.4900 - Val F1: 0.4900 - LR: 0.01
# Epoch 180/10000 - Train Loss: 0.6772 - Val Precision: 0.4900 - Val Recall: 0.4900 - Val F1: 0.4900 - LR: 0.01
# Epoch 190/10000 - Train Loss: 0.6755 - Val Precision: 0.4900 - Val Recall: 0.4900 - Val F1: 0.4900 - LR: 0.01
# Epoch 200/10000 - Train Loss: 0.6736 - Val Precision: 0.4900 - Val Recall: 0.4900 - Val F1: 0.4900 - LR: 0.01
# Epoch 210/10000 - Train Loss: 0.6713 - Val Precision: 0.4900 - Val Recall: 0.4900 - Val F1: 0.4900 - LR: 0.01
# Epoch 220/10000 - Train Loss: 0.6687 - Val Precision: 0.4900 - Val Recall: 0.4900 - Val F1: 0.4900 - LR: 0.01
# Epoch 230/10000 - Train Loss: 0.6656 - Val Precision: 0.4900 - Val Recall: 0.4900 - Val F1: 0.4900 - LR: 0.01
# Epoch 240/10000 - Train Loss: 0.6621 - Val Precision: 0.4900 - Val Recall: 0.4900 - Val F1: 0.4900 - LR: 0.01
# Epoch 250/10000 - Train Loss: 0.6580 - Val Precision: 0.4900 - Val Recall: 0.4900 - Val F1: 0.4900 - LR: 0.01
# Epoch 260/10000 - Train Loss: 0.6560 - Val Precision: 0.5900 - Val Recall: 0.5900 - Val F1: 0.5900 - LR: 0.01
# Epoch 270/10000 - Train Loss: 0.6516 - Val Precision: 0.5050 - Val Recall: 0.5050 - Val F1: 0.5050 - LR: 0.01
# Epoch 280/10000 - Train Loss: 0.6472 - Val Precision: 0.5150 - Val Recall: 0.5150 - Val F1: 0.5150 - LR: 0.01
# Epoch 290/10000 - Train Loss: 0.6431 - Val Precision: 0.5100 - Val Recall: 0.5100 - Val F1: 0.5100 - LR: 0.01
# Epoch 300/10000 - Train Loss: 0.6395 - Val Precision: 0.5250 - Val Recall: 0.5250 - Val F1: 0.5250 - LR: 0.01
# Epoch 310/10000 - Train Loss: 0.6354 - Val Precision: 0.5300 - Val Recall: 0.5300 - Val F1: 0.5300 - LR: 0.01
# Epoch 320/10000 - Train Loss: 0.6312 - Val Precision: 0.5400 - Val Recall: 0.5400 - Val F1: 0.5400 - LR: 0.01
# Epoch 330/10000 - Train Loss: 0.6266 - Val Precision: 0.5500 - Val Recall: 0.5500 - Val F1: 0.5500 - LR: 0.01
# Epoch 340/10000 - Train Loss: 0.6218 - Val Precision: 0.6000 - Val Recall: 0.6000 - Val F1: 0.6000 - LR: 0.01
# Epoch 350/10000 - Train Loss: 0.6185 - Val Precision: 0.6850 - Val Recall: 0.6850 - Val F1: 0.6850 - LR: 0.01
# Epoch 360/10000 - Train Loss: 0.6125 - Val Precision: 0.5900 - Val Recall: 0.5900 - Val F1: 0.5900 - LR: 0.01
# Epoch 370/10000 - Train Loss: 0.6079 - Val Precision: 0.6750 - Val Recall: 0.6750 - Val F1: 0.6750 - LR: 0.01
# Epoch 380/10000 - Train Loss: 0.6034 - Val Precision: 0.6450 - Val Recall: 0.6450 - Val F1: 0.6450 - LR: 0.01
# Epoch 390/10000 - Train Loss: 0.5989 - Val Precision: 0.6600 - Val Recall: 0.6600 - Val F1: 0.6600 - LR: 0.01
# Epoch 400/10000 - Train Loss: 0.5941 - Val Precision: 0.6650 - Val Recall: 0.6650 - Val F1: 0.6650 - LR: 0.01
# Epoch 410/10000 - Train Loss: 0.5891 - Val Precision: 0.7050 - Val Recall: 0.7050 - Val F1: 0.7050 - LR: 0.01
# Epoch 420/10000 - Train Loss: 0.5851 - Val Precision: 0.6700 - Val Recall: 0.6700 - Val F1: 0.6700 - LR: 0.01
# Epoch 430/10000 - Train Loss: 0.5801 - Val Precision: 0.7200 - Val Recall: 0.7200 - Val F1: 0.7200 - LR: 0.01
# Epoch 440/10000 - Train Loss: 0.5759 - Val Precision: 0.7350 - Val Recall: 0.7350 - Val F1: 0.7350 - LR: 0.01
# Epoch 450/10000 - Train Loss: 0.5710 - Val Precision: 0.7600 - Val Recall: 0.7600 - Val F1: 0.7600 - LR: 0.01
# Epoch 460/10000 - Train Loss: 0.5664 - Val Precision: 0.7600 - Val Recall: 0.7600 - Val F1: 0.7600 - LR: 0.01
# Epoch 470/10000 - Train Loss: 0.5618 - Val Precision: 0.7650 - Val Recall: 0.7650 - Val F1: 0.7650 - LR: 0.01
# Epoch 480/10000 - Train Loss: 0.5597 - Val Precision: 0.7500 - Val Recall: 0.7500 - Val F1: 0.7500 - LR: 0.01
# Epoch 490/10000 - Train Loss: 0.5534 - Val Precision: 0.7650 - Val Recall: 0.7650 - Val F1: 0.7650 - LR: 0.01
# Epoch 500/10000 - Train Loss: 0.5482 - Val Precision: 0.7900 - Val Recall: 0.7900 - Val F1: 0.7900 - LR: 0.01
# Epoch 510/10000 - Train Loss: 0.5440 - Val Precision: 0.7900 - Val Recall: 0.7900 - Val F1: 0.7900 - LR: 0.01
# Epoch 520/10000 - Train Loss: 0.5396 - Val Precision: 0.7950 - Val Recall: 0.7950 - Val F1: 0.7950 - LR: 0.01
# Epoch 530/10000 - Train Loss: 0.5380 - Val Precision: 0.8100 - Val Recall: 0.8100 - Val F1: 0.8100 - LR: 0.01
# Epoch 540/10000 - Train Loss: 0.5314 - Val Precision: 0.8100 - Val Recall: 0.8100 - Val F1: 0.8100 - LR: 0.01
# Epoch 550/10000 - Train Loss: 0.5268 - Val Precision: 0.8250 - Val Recall: 0.8250 - Val F1: 0.8250 - LR: 0.01
# Epoch 560/10000 - Train Loss: 0.5225 - Val Precision: 0.8250 - Val Recall: 0.8250 - Val F1: 0.8250 - LR: 0.01
# Epoch 570/10000 - Train Loss: 0.5195 - Val Precision: 0.8200 - Val Recall: 0.8200 - Val F1: 0.8200 - LR: 0.01
# Epoch 580/10000 - Train Loss: 0.5144 - Val Precision: 0.8350 - Val Recall: 0.8350 - Val F1: 0.8350 - LR: 0.01
# Epoch 590/10000 - Train Loss: 0.5103 - Val Precision: 0.8250 - Val Recall: 0.8250 - Val F1: 0.8250 - LR: 0.01
# Epoch 600/10000 - Train Loss: 0.5077 - Val Precision: 0.8250 - Val Recall: 0.8250 - Val F1: 0.8250 - LR: 0.01
# Epoch 610/10000 - Train Loss: 0.5027 - Val Precision: 0.8400 - Val Recall: 0.8400 - Val F1: 0.8400 - LR: 0.01
# Epoch 620/10000 - Train Loss: 0.5001 - Val Precision: 0.8350 - Val Recall: 0.8350 - Val F1: 0.8350 - LR: 0.01
# Epoch 630/10000 - Train Loss: 0.4952 - Val Precision: 0.8350 - Val Recall: 0.8350 - Val F1: 0.8350 - LR: 0.01
# Epoch 640/10000 - Train Loss: 0.4918 - Val Precision: 0.8450 - Val Recall: 0.8450 - Val F1: 0.8450 - LR: 0.01
# Epoch 650/10000 - Train Loss: 0.4876 - Val Precision: 0.8450 - Val Recall: 0.8450 - Val F1: 0.8450 - LR: 0.01
# Epoch 660/10000 - Train Loss: 0.4839 - Val Precision: 0.8500 - Val Recall: 0.8500 - Val F1: 0.8500 - LR: 0.01
# Epoch 670/10000 - Train Loss: 0.4816 - Val Precision: 0.8550 - Val Recall: 0.8550 - Val F1: 0.8550 - LR: 0.01
# Epoch 680/10000 - Train Loss: 0.4784 - Val Precision: 0.8500 - Val Recall: 0.8500 - Val F1: 0.8500 - LR: 0.01
# Epoch 690/10000 - Train Loss: 0.4739 - Val Precision: 0.8550 - Val Recall: 0.8550 - Val F1: 0.8550 - LR: 0.01
# Epoch 700/10000 - Train Loss: 0.4707 - Val Precision: 0.8550 - Val Recall: 0.8550 - Val F1: 0.8550 - LR: 0.01
# Epoch 710/10000 - Train Loss: 0.4673 - Val Precision: 0.8600 - Val Recall: 0.8600 - Val F1: 0.8600 - LR: 0.01
# Epoch 720/10000 - Train Loss: 0.4662 - Val Precision: 0.8450 - Val Recall: 0.8450 - Val F1: 0.8450 - LR: 0.01
# Epoch 730/10000 - Train Loss: 0.4617 - Val Precision: 0.8500 - Val Recall: 0.8500 - Val F1: 0.8500 - LR: 0.01
# Epoch 740/10000 - Train Loss: 0.4582 - Val Precision: 0.8550 - Val Recall: 0.8550 - Val F1: 0.8550 - LR: 0.01
# Epoch 750/10000 - Train Loss: 0.4545 - Val Precision: 0.8700 - Val Recall: 0.8700 - Val F1: 0.8700 - LR: 0.01
# Epoch 760/10000 - Train Loss: 0.4530 - Val Precision: 0.8400 - Val Recall: 0.8400 - Val F1: 0.8400 - LR: 0.01
# Epoch 770/10000 - Train Loss: 0.4482 - Val Precision: 0.8650 - Val Recall: 0.8650 - Val F1: 0.8650 - LR: 0.01
# Epoch 780/10000 - Train Loss: 0.4467 - Val Precision: 0.8600 - Val Recall: 0.8600 - Val F1: 0.8600 - LR: 0.01
# Epoch 790/10000 - Train Loss: 0.4422 - Val Precision: 0.8700 - Val Recall: 0.8700 - Val F1: 0.8700 - LR: 0.01
# Epoch 800/10000 - Train Loss: 0.4419 - Val Precision: 0.8300 - Val Recall: 0.8300 - Val F1: 0.8300 - LR: 0.01
# Epoch 810/10000 - Train Loss: 0.4366 - Val Precision: 0.8650 - Val Recall: 0.8650 - Val F1: 0.8650 - LR: 0.01
# Epoch 820/10000 - Train Loss: 0.4361 - Val Precision: 0.8600 - Val Recall: 0.8600 - Val F1: 0.8600 - LR: 0.01
# Epoch 830/10000 - Train Loss: 0.4318 - Val Precision: 0.8500 - Val Recall: 0.8500 - Val F1: 0.8500 - LR: 0.01
# Epoch 840/10000 - Train Loss: 0.4282 - Val Precision: 0.8750 - Val Recall: 0.8750 - Val F1: 0.8750 - LR: 0.01
# Epoch 850/10000 - Train Loss: 0.4268 - Val Precision: 0.8600 - Val Recall: 0.8600 - Val F1: 0.8600 - LR: 0.01
# Epoch 860/10000 - Train Loss: 0.4261 - Val Precision: 0.8350 - Val Recall: 0.8350 - Val F1: 0.8350 - LR: 0.01
# Epoch 870/10000 - Train Loss: 0.4225 - Val Precision: 0.8650 - Val Recall: 0.8650 - Val F1: 0.8650 - LR: 0.01
# Epoch 880/10000 - Train Loss: 0.4193 - Val Precision: 0.8350 - Val Recall: 0.8350 - Val F1: 0.8350 - LR: 0.01
# Epoch 890/10000 - Train Loss: 0.4153 - Val Precision: 0.8650 - Val Recall: 0.8650 - Val F1: 0.8650 - LR: 0.01
# Epoch 900/10000 - Train Loss: 0.4134 - Val Precision: 0.8650 - Val Recall: 0.8650 - Val F1: 0.8650 - LR: 0.01
# Epoch 910/10000 - Train Loss: 0.4103 - Val Precision: 0.8800 - Val Recall: 0.8800 - Val F1: 0.8800 - LR: 0.01
# Epoch 920/10000 - Train Loss: 0.4091 - Val Precision: 0.8350 - Val Recall: 0.8350 - Val F1: 0.8350 - LR: 0.01
# Epoch 930/10000 - Train Loss: 0.4072 - Val Precision: 0.8700 - Val Recall: 0.8700 - Val F1: 0.8700 - LR: 0.01
# Epoch 940/10000 - Train Loss: 0.4049 - Val Precision: 0.8650 - Val Recall: 0.8650 - Val F1: 0.8650 - LR: 0.01
# Epoch 950/10000 - Train Loss: 0.4010 - Val Precision: 0.8700 - Val Recall: 0.8700 - Val F1: 0.8700 - LR: 0.01
# Epoch 960/10000 - Train Loss: 0.4012 - Val Precision: 0.8700 - Val Recall: 0.8700 - Val F1: 0.8700 - LR: 0.01
# Epoch 970/10000 - Train Loss: 0.3978 - Val Precision: 0.8750 - Val Recall: 0.8750 - Val F1: 0.8750 - LR: 0.01
# Epoch 980/10000 - Train Loss: 0.3942 - Val Precision: 0.8800 - Val Recall: 0.8800 - Val F1: 0.8800 - LR: 0.01
# Epoch 990/10000 - Train Loss: 0.3922 - Val Precision: 0.8700 - Val Recall: 0.8700 - Val F1: 0.8700 - LR: 0.01
# Epoch 1000/10000 - Train Loss: 0.3911 - Val Precision: 0.8550 - Val Recall: 0.8550 - Val F1: 0.8550 - LR: 0.01
# Epoch 1010/10000 - Train Loss: 0.3889 - Val Precision: 0.8600 - Val Recall: 0.8600 - Val F1: 0.8600 - LR: 0.01
# Epoch 1020/10000 - Train Loss: 0.3861 - Val Precision: 0.8700 - Val Recall: 0.8700 - Val F1: 0.8700 - LR: 0.01
# Epoch 1030/10000 - Train Loss: 0.3852 - Val Precision: 0.8400 - Val Recall: 0.8400 - Val F1: 0.8400 - LR: 0.01
# Epoch 1040/10000 - Train Loss: 0.3816 - Val Precision: 0.8800 - Val Recall: 0.8800 - Val F1: 0.8800 - LR: 0.01
# Epoch 1050/10000 - Train Loss: 0.3797 - Val Precision: 0.8800 - Val Recall: 0.8800 - Val F1: 0.8800 - LR: 0.01
# Epoch 1060/10000 - Train Loss: 0.3795 - Val Precision: 0.8300 - Val Recall: 0.8300 - Val F1: 0.8300 - LR: 0.01
# Epoch 1070/10000 - Train Loss: 0.3787 - Val Precision: 0.7250 - Val Recall: 0.7250 - Val F1: 0.7250 - LR: 0.01
# Epoch 1080/10000 - Train Loss: 0.5334 - Val Precision: 0.6450 - Val Recall: 0.6450 - Val F1: 0.6450 - LR: 0.01
# Epoch 1090/10000 - Train Loss: 0.3931 - Val Precision: 0.6500 - Val Recall: 0.6500 - Val F1: 0.6500 - LR: 0.01
# Epoch 1100/10000 - Train Loss: 0.4980 - Val Precision: 0.6450 - Val Recall: 0.6450 - Val F1: 0.6450 - LR: 0.01
# Epoch 1110/10000 - Train Loss: 0.4044 - Val Precision: 0.8300 - Val Recall: 0.8300 - Val F1: 0.8300 - LR: 0.01
# Epoch 1120/10000 - Train Loss: 0.4964 - Val Precision: 0.6650 - Val Recall: 0.6650 - Val F1: 0.6650 - LR: 0.01
# Epoch 1130/10000 - Train Loss: 0.4104 - Val Precision: 0.7850 - Val Recall: 0.7850 - Val F1: 0.7850 - LR: 0.01
# Epoch 1140/10000 - Train Loss: 0.4864 - Val Precision: 0.6200 - Val Recall: 0.6200 - Val F1: 0.6200 - LR: 0.01
# Epoch 1150/10000 - Train Loss: 0.4097 - Val Precision: 0.8450 - Val Recall: 0.8450 - Val F1: 0.8450 - LR: 0.01
# Epoch 1160/10000 - Train Loss: 0.4042 - Val Precision: 0.8700 - Val Recall: 0.8700 - Val F1: 0.8700 - LR: 0.01
# Epoch 1170/10000 - Train Loss: 0.3763 - Val Precision: 0.8100 - Val Recall: 0.8100 - Val F1: 0.8100 - LR: 0.01
# Epoch 1180/10000 - Train Loss: 0.3841 - Val Precision: 0.8450 - Val Recall: 0.8450 - Val F1: 0.8450 - LR: 0.01
# Epoch 1190/10000 - Train Loss: 0.3754 - Val Precision: 0.7700 - Val Recall: 0.7700 - Val F1: 0.7700 - LR: 0.01
# Epoch 1200/10000 - Train Loss: 0.3900 - Val Precision: 0.8300 - Val Recall: 0.8300 - Val F1: 0.8300 - LR: 0.01
# Epoch 1210/10000 - Train Loss: 0.3797 - Val Precision: 0.8350 - Val Recall: 0.8350 - Val F1: 0.8350 - LR: 0.01
# Epoch 1220/10000 - Train Loss: 0.3944 - Val Precision: 0.8550 - Val Recall: 0.8550 - Val F1: 0.8550 - LR: 0.01
# Epoch 1230/10000 - Train Loss: 0.3831 - Val Precision: 0.8200 - Val Recall: 0.8200 - Val F1: 0.8200 - LR: 0.01
# Epoch 1240/10000 - Train Loss: 0.3819 - Val Precision: 0.8300 - Val Recall: 0.8300 - Val F1: 0.8300 - LR: 0.01
# Epoch 1250/10000 - Train Loss: 0.4165 - Val Precision: 0.7800 - Val Recall: 0.7800 - Val F1: 0.7800 - LR: 0.01
# Epoch 1260/10000 - Train Loss: 0.3837 - Val Precision: 0.8300 - Val Recall: 0.8300 - Val F1: 0.8300 - LR: 0.01
# Epoch 1270/10000 - Train Loss: 0.3719 - Val Precision: 0.8550 - Val Recall: 0.8550 - Val F1: 0.8550 - LR: 0.01
# Epoch 1280/10000 - Train Loss: 0.3838 - Val Precision: 0.8600 - Val Recall: 0.8600 - Val F1: 0.8600 - LR: 0.01
# Epoch 1290/10000 - Train Loss: 0.3842 - Val Precision: 0.7450 - Val Recall: 0.7450 - Val F1: 0.7450 - LR: 0.01
# Epoch 1300/10000 - Train Loss: 0.3892 - Val Precision: 0.8700 - Val Recall: 0.8700 - Val F1: 0.8700 - LR: 0.01
# Epoch 1310/10000 - Train Loss: 0.3833 - Val Precision: 0.8700 - Val Recall: 0.8700 - Val F1: 0.8700 - LR: 0.01
# Epoch 1320/10000 - Train Loss: 0.3714 - Val Precision: 0.8150 - Val Recall: 0.8150 - Val F1: 0.8150 - LR: 0.01
# Epoch 1330/10000 - Train Loss: 0.3859 - Val Precision: 0.8800 - Val Recall: 0.8800 - Val F1: 0.8800 - LR: 0.01
# Epoch 1340/10000 - Train Loss: 0.3945 - Val Precision: 0.8450 - Val Recall: 0.8450 - Val F1: 0.8450 - LR: 0.01
# Epoch 1350/10000 - Train Loss: 0.4170 - Val Precision: 0.6650 - Val Recall: 0.6650 - Val F1: 0.6650 - LR: 0.01
# Epoch 1360/10000 - Train Loss: 0.3710 - Val Precision: 0.8250 - Val Recall: 0.8250 - Val F1: 0.8250 - LR: 0.01
# Epoch 1370/10000 - Train Loss: 0.3664 - Val Precision: 0.8600 - Val Recall: 0.8600 - Val F1: 0.8600 - LR: 0.01
# Epoch 1380/10000 - Train Loss: 0.3633 - Val Precision: 0.8700 - Val Recall: 0.8700 - Val F1: 0.8700 - LR: 0.01
# Epoch 1390/10000 - Train Loss: 0.3622 - Val Precision: 0.8850 - Val Recall: 0.8850 - Val F1: 0.8850 - LR: 0.01
# Epoch 1400/10000 - Train Loss: 0.3606 - Val Precision: 0.8800 - Val Recall: 0.8800 - Val F1: 0.8800 - LR: 0.01
# Epoch 1410/10000 - Train Loss: 0.3591 - Val Precision: 0.8750 - Val Recall: 0.8750 - Val F1: 0.8750 - LR: 0.01
# Epoch 1420/10000 - Train Loss: 0.3577 - Val Precision: 0.8800 - Val Recall: 0.8800 - Val F1: 0.8800 - LR: 0.01
# Epoch 1430/10000 - Train Loss: 0.3563 - Val Precision: 0.8800 - Val Recall: 0.8800 - Val F1: 0.8800 - LR: 0.01
# Epoch 1440/10000 - Train Loss: 0.3548 - Val Precision: 0.8800 - Val Recall: 0.8800 - Val F1: 0.8800 - LR: 0.01
# Epoch 1450/10000 - Train Loss: 0.3534 - Val Precision: 0.8800 - Val Recall: 0.8800 - Val F1: 0.8800 - LR: 0.01
# Epoch 1460/10000 - Train Loss: 0.3520 - Val Precision: 0.8800 - Val Recall: 0.8800 - Val F1: 0.8800 - LR: 0.01
# Epoch 1470/10000 - Train Loss: 0.3506 - Val Precision: 0.8800 - Val Recall: 0.8800 - Val F1: 0.8800 - LR: 0.01
# Epoch 1480/10000 - Train Loss: 0.3492 - Val Precision: 0.8800 - Val Recall: 0.8800 - Val F1: 0.8800 - LR: 0.01
# Epoch 1490/10000 - Train Loss: 0.3478 - Val Precision: 0.8800 - Val Recall: 0.8800 - Val F1: 0.8800 - LR: 0.01
# Epoch 1500/10000 - Train Loss: 0.3464 - Val Precision: 0.8800 - Val Recall: 0.8800 - Val F1: 0.8800 - LR: 0.01
# Epoch 1510/10000 - Train Loss: 0.3450 - Val Precision: 0.8800 - Val Recall: 0.8800 - Val F1: 0.8800 - LR: 0.01
# Epoch 1520/10000 - Train Loss: 0.3436 - Val Precision: 0.8800 - Val Recall: 0.8800 - Val F1: 0.8800 - LR: 0.01
# Epoch 1530/10000 - Train Loss: 0.3422 - Val Precision: 0.8800 - Val Recall: 0.8800 - Val F1: 0.8800 - LR: 0.01
# Epoch 1540/10000 - Train Loss: 0.3408 - Val Precision: 0.8800 - Val Recall: 0.8800 - Val F1: 0.8800 - LR: 0.01
# Epoch 1550/10000 - Train Loss: 0.3394 - Val Precision: 0.8800 - Val Recall: 0.8800 - Val F1: 0.8800 - LR: 0.01
# Epoch 1560/10000 - Train Loss: 0.3380 - Val Precision: 0.8800 - Val Recall: 0.8800 - Val F1: 0.8800 - LR: 0.01
# Epoch 1570/10000 - Train Loss: 0.3366 - Val Precision: 0.8800 - Val Recall: 0.8800 - Val F1: 0.8800 - LR: 0.01
# Epoch 1580/10000 - Train Loss: 0.3353 - Val Precision: 0.8800 - Val Recall: 0.8800 - Val F1: 0.8800 - LR: 0.01
# Epoch 1590/10000 - Train Loss: 0.3339 - Val Precision: 0.8750 - Val Recall: 0.8750 - Val F1: 0.8750 - LR: 0.01
# Epoch 1600/10000 - Train Loss: 0.3325 - Val Precision: 0.8750 - Val Recall: 0.8750 - Val F1: 0.8750 - LR: 0.01
# Epoch 1610/10000 - Train Loss: 0.3312 - Val Precision: 0.8700 - Val Recall: 0.8700 - Val F1: 0.8700 - LR: 0.01
# Epoch 1620/10000 - Train Loss: 0.3301 - Val Precision: 0.8550 - Val Recall: 0.8550 - Val F1: 0.8550 - LR: 0.01
# Epoch 1630/10000 - Train Loss: 0.3286 - Val Precision: 0.8850 - Val Recall: 0.8850 - Val F1: 0.8850 - LR: 0.01
# Epoch 1640/10000 - Train Loss: 0.3277 - Val Precision: 0.8800 - Val Recall: 0.8800 - Val F1: 0.8800 - LR: 0.01
# Epoch 1650/10000 - Train Loss: 0.3272 - Val Precision: 0.8500 - Val Recall: 0.8500 - Val F1: 0.8500 - LR: 0.01
# Epoch 1660/10000 - Train Loss: 0.3247 - Val Precision: 0.8700 - Val Recall: 0.8700 - Val F1: 0.8700 - LR: 0.01
# Epoch 1670/10000 - Train Loss: 0.3256 - Val Precision: 0.8900 - Val Recall: 0.8900 - Val F1: 0.8900 - LR: 0.01
# Epoch 1680/10000 - Train Loss: 0.3232 - Val Precision: 0.8900 - Val Recall: 0.8900 - Val F1: 0.8900 - LR: 0.01
# Epoch 1690/10000 - Train Loss: 0.3222 - Val Precision: 0.8900 - Val Recall: 0.8900 - Val F1: 0.8900 - LR: 0.01
# Epoch 1700/10000 - Train Loss: 0.3201 - Val Precision: 0.8850 - Val Recall: 0.8850 - Val F1: 0.8850 - LR: 0.01
# Epoch 1710/10000 - Train Loss: 0.3195 - Val Precision: 0.8850 - Val Recall: 0.8850 - Val F1: 0.8850 - LR: 0.01
# Epoch 1720/10000 - Train Loss: 0.3176 - Val Precision: 0.8700 - Val Recall: 0.8700 - Val F1: 0.8700 - LR: 0.01
# Epoch 1730/10000 - Train Loss: 0.3165 - Val Precision: 0.8850 - Val Recall: 0.8850 - Val F1: 0.8850 - LR: 0.01
# Epoch 1740/10000 - Train Loss: 0.3170 - Val Precision: 0.8750 - Val Recall: 0.8750 - Val F1: 0.8750 - LR: 0.01
# Epoch 1750/10000 - Train Loss: 0.3203 - Val Precision: 0.8450 - Val Recall: 0.8450 - Val F1: 0.8450 - LR: 0.01
# Epoch 1760/10000 - Train Loss: 0.3275 - Val Precision: 0.8900 - Val Recall: 0.8900 - Val F1: 0.8900 - LR: 0.01
# Epoch 1770/10000 - Train Loss: 0.3429 - Val Precision: 0.8250 - Val Recall: 0.8250 - Val F1: 0.8250 - LR: 0.01
# Epoch 1780/10000 - Train Loss: 0.3180 - Val Precision: 0.8850 - Val Recall: 0.8850 - Val F1: 0.8850 - LR: 0.01
# Epoch 1790/10000 - Train Loss: 0.3284 - Val Precision: 0.8400 - Val Recall: 0.8400 - Val F1: 0.8400 - LR: 0.01
# Epoch 1800/10000 - Train Loss: 0.3179 - Val Precision: 0.8800 - Val Recall: 0.8800 - Val F1: 0.8800 - LR: 0.01
# Epoch 1810/10000 - Train Loss: 0.3225 - Val Precision: 0.8400 - Val Recall: 0.8400 - Val F1: 0.8400 - LR: 0.01
# Epoch 1820/10000 - Train Loss: 0.3162 - Val Precision: 0.8800 - Val Recall: 0.8800 - Val F1: 0.8800 - LR: 0.01
# Epoch 1830/10000 - Train Loss: 0.3156 - Val Precision: 0.8450 - Val Recall: 0.8450 - Val F1: 0.8450 - LR: 0.01
# Epoch 1840/10000 - Train Loss: 0.3173 - Val Precision: 0.8800 - Val Recall: 0.8800 - Val F1: 0.8800 - LR: 0.01
# Epoch 1850/10000 - Train Loss: 0.3215 - Val Precision: 0.8400 - Val Recall: 0.8400 - Val F1: 0.8400 - LR: 0.01
# Epoch 1860/10000 - Train Loss: 0.3135 - Val Precision: 0.8750 - Val Recall: 0.8750 - Val F1: 0.8750 - LR: 0.01
# Epoch 1870/10000 - Train Loss: 0.3218 - Val Precision: 0.8400 - Val Recall: 0.8400 - Val F1: 0.8400 - LR: 0.01
# Epoch 1880/10000 - Train Loss: 0.3164 - Val Precision: 0.8750 - Val Recall: 0.8750 - Val F1: 0.8750 - LR: 0.01
# Epoch 1890/10000 - Train Loss: 0.3100 - Val Precision: 0.8550 - Val Recall: 0.8550 - Val F1: 0.8550 - LR: 0.01
# Epoch 1900/10000 - Train Loss: 0.3077 - Val Precision: 0.8650 - Val Recall: 0.8650 - Val F1: 0.8650 - LR: 0.01
# Epoch 1910/10000 - Train Loss: 0.3067 - Val Precision: 0.8850 - Val Recall: 0.8850 - Val F1: 0.8850 - LR: 0.01
# Epoch 1920/10000 - Train Loss: 0.3057 - Val Precision: 0.8650 - Val Recall: 0.8650 - Val F1: 0.8650 - LR: 0.01
# Epoch 1930/10000 - Train Loss: 0.3046 - Val Precision: 0.8700 - Val Recall: 0.8700 - Val F1: 0.8700 - LR: 0.01
# Epoch 1940/10000 - Train Loss: 0.3036 - Val Precision: 0.8850 - Val Recall: 0.8850 - Val F1: 0.8850 - LR: 0.01
# Epoch 1950/10000 - Train Loss: 0.3028 - Val Precision: 0.8850 - Val Recall: 0.8850 - Val F1: 0.8850 - LR: 0.01
# Epoch 1960/10000 - Train Loss: 0.3015 - Val Precision: 0.8600 - Val Recall: 0.8600 - Val F1: 0.8600 - LR: 0.01
# Epoch 1970/10000 - Train Loss: 0.3006 - Val Precision: 0.8850 - Val Recall: 0.8850 - Val F1: 0.8850 - LR: 0.01
# Epoch 1980/10000 - Train Loss: 0.2999 - Val Precision: 0.8850 - Val Recall: 0.8850 - Val F1: 0.8850 - LR: 0.01
# Epoch 1990/10000 - Train Loss: 0.3003 - Val Precision: 0.8900 - Val Recall: 0.8900 - Val F1: 0.8900 - LR: 0.01
# Epoch 2000/10000 - Train Loss: 0.2976 - Val Precision: 0.8600 - Val Recall: 0.8600 - Val F1: 0.8600 - LR: 0.01
# Epoch 2010/10000 - Train Loss: 0.2966 - Val Precision: 0.8450 - Val Recall: 0.8450 - Val F1: 0.8450 - LR: 0.01
# Epoch 2020/10000 - Train Loss: 0.2959 - Val Precision: 0.8650 - Val Recall: 0.8650 - Val F1: 0.8650 - LR: 0.01
# Epoch 2030/10000 - Train Loss: 0.2967 - Val Precision: 0.8400 - Val Recall: 0.8400 - Val F1: 0.8400 - LR: 0.01
# Epoch 2040/10000 - Train Loss: 0.3062 - Val Precision: 0.8850 - Val Recall: 0.8850 - Val F1: 0.8850 - LR: 0.01
# Epoch 2050/10000 - Train Loss: 0.3084 - Val Precision: 0.8600 - Val Recall: 0.8600 - Val F1: 0.8600 - LR: 0.01
# Epoch 2060/10000 - Train Loss: 0.2943 - Val Precision: 0.8900 - Val Recall: 0.8900 - Val F1: 0.8900 - LR: 0.01
# Epoch 2070/10000 - Train Loss: 0.2934 - Val Precision: 0.8800 - Val Recall: 0.8800 - Val F1: 0.8800 - LR: 0.01
# Epoch 2080/10000 - Train Loss: 0.3158 - Val Precision: 0.8800 - Val Recall: 0.8800 - Val F1: 0.8800 - LR: 0.01
# Epoch 2090/10000 - Train Loss: 0.3179 - Val Precision: 0.7600 - Val Recall: 0.7600 - Val F1: 0.7600 - LR: 0.01
# Epoch 2100/10000 - Train Loss: 0.3166 - Val Precision: 0.8750 - Val Recall: 0.8750 - Val F1: 0.8750 - LR: 0.01
# Epoch 2110/10000 - Train Loss: 0.3134 - Val Precision: 0.8800 - Val Recall: 0.8800 - Val F1: 0.8800 - LR: 0.01
# Epoch 2120/10000 - Train Loss: 0.3228 - Val Precision: 0.7600 - Val Recall: 0.7600 - Val F1: 0.7600 - LR: 0.01
# Epoch 2130/10000 - Train Loss: 0.3479 - Val Precision: 0.8600 - Val Recall: 0.8600 - Val F1: 0.8600 - LR: 0.01
# Epoch 2140/10000 - Train Loss: 0.3252 - Val Precision: 0.8900 - Val Recall: 0.8900 - Val F1: 0.8900 - LR: 0.01
# Epoch 2150/10000 - Train Loss: 0.2923 - Val Precision: 0.7950 - Val Recall: 0.7950 - Val F1: 0.7950 - LR: 0.01
# Epoch 2160/10000 - Train Loss: 0.3050 - Val Precision: 0.8800 - Val Recall: 0.8800 - Val F1: 0.8800 - LR: 0.01
# Epoch 2170/10000 - Train Loss: 0.2942 - Val Precision: 0.8550 - Val Recall: 0.8550 - Val F1: 0.8550 - LR: 0.01
# Epoch 2180/10000 - Train Loss: 0.3006 - Val Precision: 0.8750 - Val Recall: 0.8750 - Val F1: 0.8750 - LR: 0.001
# Epoch 2190/10000 - Train Loss: 0.2925 - Val Precision: 0.8900 - Val Recall: 0.8900 - Val F1: 0.8900 - LR: 0.001
# Epoch 2200/10000 - Train Loss: 0.2918 - Val Precision: 0.8900 - Val Recall: 0.8900 - Val F1: 0.8900 - LR: 0.001
# Epoch 2210/10000 - Train Loss: 0.2915 - Val Precision: 0.8850 - Val Recall: 0.8850 - Val F1: 0.8850 - LR: 0.001
# Epoch 2220/10000 - Train Loss: 0.2914 - Val Precision: 0.8800 - Val Recall: 0.8800 - Val F1: 0.8800 - LR: 0.001
# Epoch 2230/10000 - Train Loss: 0.2912 - Val Precision: 0.8700 - Val Recall: 0.8700 - Val F1: 0.8700 - LR: 0.001
# Epoch 2240/10000 - Train Loss: 0.2911 - Val Precision: 0.8700 - Val Recall: 0.8700 - Val F1: 0.8700 - LR: 0.001
# Epoch 2250/10000 - Train Loss: 0.2910 - Val Precision: 0.8700 - Val Recall: 0.8700 - Val F1: 0.8700 - LR: 0.001
# Epoch 2260/10000 - Train Loss: 0.2909 - Val Precision: 0.8700 - Val Recall: 0.8700 - Val F1: 0.8700 - LR: 0.001
# Epoch 2270/10000 - Train Loss: 0.2908 - Val Precision: 0.8700 - Val Recall: 0.8700 - Val F1: 0.8700 - LR: 0.001
# Epoch 2280/10000 - Train Loss: 0.2908 - Val Precision: 0.8700 - Val Recall: 0.8700 - Val F1: 0.8700 - LR: 0.001
# Epoch 2290/10000 - Train Loss: 0.2907 - Val Precision: 0.8700 - Val Recall: 0.8700 - Val F1: 0.8700 - LR: 0.001
# Epoch 2300/10000 - Train Loss: 0.2906 - Val Precision: 0.8700 - Val Recall: 0.8700 - Val F1: 0.8700 - LR: 0.001
# Epoch 2310/10000 - Train Loss: 0.2905 - Val Precision: 0.8700 - Val Recall: 0.8700 - Val F1: 0.8700 - LR: 0.001
# Epoch 2320/10000 - Train Loss: 0.2904 - Val Precision: 0.8700 - Val Recall: 0.8700 - Val F1: 0.8700 - LR: 0.001
# Epoch 2330/10000 - Train Loss: 0.2903 - Val Precision: 0.8700 - Val Recall: 0.8700 - Val F1: 0.8700 - LR: 0.001
# Epoch 2340/10000 - Train Loss: 0.2902 - Val Precision: 0.8700 - Val Recall: 0.8700 - Val F1: 0.8700 - LR: 0.001
# Epoch 2350/10000 - Train Loss: 0.2901 - Val Precision: 0.8700 - Val Recall: 0.8700 - Val F1: 0.8700 - LR: 0.001
# Epoch 2360/10000 - Train Loss: 0.2900 - Val Precision: 0.8700 - Val Recall: 0.8700 - Val F1: 0.8700 - LR: 0.001
# Epoch 2370/10000 - Train Loss: 0.2899 - Val Precision: 0.8700 - Val Recall: 0.8700 - Val F1: 0.8700 - LR: 0.001
# Epoch 2380/10000 - Train Loss: 0.2898 - Val Precision: 0.8700 - Val Recall: 0.8700 - Val F1: 0.8700 - LR: 0.001
# Epoch 2390/10000 - Train Loss: 0.2897 - Val Precision: 0.8700 - Val Recall: 0.8700 - Val F1: 0.8700 - LR: 0.001
# Epoch 2400/10000 - Train Loss: 0.2896 - Val Precision: 0.8700 - Val Recall: 0.8700 - Val F1: 0.8700 - LR: 0.001
# Epoch 2410/10000 - Train Loss: 0.2895 - Val Precision: 0.8700 - Val Recall: 0.8700 - Val F1: 0.8700 - LR: 0.001
# Epoch 2420/10000 - Train Loss: 0.2894 - Val Precision: 0.8700 - Val Recall: 0.8700 - Val F1: 0.8700 - LR: 0.001
# Epoch 2430/10000 - Train Loss: 0.2893 - Val Precision: 0.8700 - Val Recall: 0.8700 - Val F1: 0.8700 - LR: 0.001
# Epoch 2440/10000 - Train Loss: 0.2892 - Val Precision: 0.8700 - Val Recall: 0.8700 - Val F1: 0.8700 - LR: 0.001
# Epoch 2450/10000 - Train Loss: 0.2891 - Val Precision: 0.8700 - Val Recall: 0.8700 - Val F1: 0.8700 - LR: 0.001
# Epoch 2460/10000 - Train Loss: 0.2890 - Val Precision: 0.8700 - Val Recall: 0.8700 - Val F1: 0.8700 - LR: 0.001
# Epoch 2470/10000 - Train Loss: 0.2889 - Val Precision: 0.8700 - Val Recall: 0.8700 - Val F1: 0.8700 - LR: 0.001
# Epoch 2480/10000 - Train Loss: 0.2888 - Val Precision: 0.8700 - Val Recall: 0.8700 - Val F1: 0.8700 - LR: 0.001
# Epoch 2490/10000 - Train Loss: 0.2887 - Val Precision: 0.8700 - Val Recall: 0.8700 - Val F1: 0.8700 - LR: 0.001
# Epoch 2500/10000 - Train Loss: 0.2885 - Val Precision: 0.8700 - Val Recall: 0.8700 - Val F1: 0.8700 - LR: 0.001
# Epoch 2510/10000 - Train Loss: 0.2884 - Val Precision: 0.8700 - Val Recall: 0.8700 - Val F1: 0.8700 - LR: 0.001
# Epoch 2520/10000 - Train Loss: 0.2883 - Val Precision: 0.8700 - Val Recall: 0.8700 - Val F1: 0.8700 - LR: 0.001
# Epoch 2530/10000 - Train Loss: 0.2882 - Val Precision: 0.8700 - Val Recall: 0.8700 - Val F1: 0.8700 - LR: 0.001
# Epoch 2540/10000 - Train Loss: 0.2881 - Val Precision: 0.8700 - Val Recall: 0.8700 - Val F1: 0.8700 - LR: 0.001
# Epoch 2550/10000 - Train Loss: 0.2880 - Val Precision: 0.8700 - Val Recall: 0.8700 - Val F1: 0.8700 - LR: 0.001
# Epoch 2560/10000 - Train Loss: 0.2879 - Val Precision: 0.8700 - Val Recall: 0.8700 - Val F1: 0.8700 - LR: 0.001
# Epoch 2570/10000 - Train Loss: 0.2878 - Val Precision: 0.8700 - Val Recall: 0.8700 - Val F1: 0.8700 - LR: 0.001
# Epoch 2580/10000 - Train Loss: 0.2877 - Val Precision: 0.8700 - Val Recall: 0.8700 - Val F1: 0.8700 - LR: 0.001
# Epoch 2590/10000 - Train Loss: 0.2876 - Val Precision: 0.8700 - Val Recall: 0.8700 - Val F1: 0.8700 - LR: 0.001
# Epoch 2600/10000 - Train Loss: 0.2875 - Val Precision: 0.8700 - Val Recall: 0.8700 - Val F1: 0.8700 - LR: 0.001
# Epoch 2610/10000 - Train Loss: 0.2874 - Val Precision: 0.8700 - Val Recall: 0.8700 - Val F1: 0.8700 - LR: 0.001
# Epoch 2620/10000 - Train Loss: 0.2872 - Val Precision: 0.8700 - Val Recall: 0.8700 - Val F1: 0.8700 - LR: 0.001
# Epoch 2630/10000 - Train Loss: 0.2871 - Val Precision: 0.8700 - Val Recall: 0.8700 - Val F1: 0.8700 - LR: 0.001
# Epoch 2640/10000 - Train Loss: 0.2870 - Val Precision: 0.8700 - Val Recall: 0.8700 - Val F1: 0.8700 - LR: 0.001
# Epoch 2650/10000 - Train Loss: 0.2869 - Val Precision: 0.8700 - Val Recall: 0.8700 - Val F1: 0.8700 - LR: 0.001
# Epoch 2660/10000 - Train Loss: 0.2868 - Val Precision: 0.8700 - Val Recall: 0.8700 - Val F1: 0.8700 - LR: 0.001
# Epoch 2670/10000 - Train Loss: 0.2867 - Val Precision: 0.8700 - Val Recall: 0.8700 - Val F1: 0.8700 - LR: 0.001
# Epoch 2680/10000 - Train Loss: 0.2866 - Val Precision: 0.8700 - Val Recall: 0.8700 - Val F1: 0.8700 - LR: 0.001
# Epoch 2690/10000 - Train Loss: 0.2864 - Val Precision: 0.8700 - Val Recall: 0.8700 - Val F1: 0.8700 - LR: 0.0001
# Epoch 2700/10000 - Train Loss: 0.2864 - Val Precision: 0.8700 - Val Recall: 0.8700 - Val F1: 0.8700 - LR: 0.0001
# Epoch 2710/10000 - Train Loss: 0.2864 - Val Precision: 0.8700 - Val Recall: 0.8700 - Val F1: 0.8700 - LR: 0.0001
# Epoch 2720/10000 - Train Loss: 0.2864 - Val Precision: 0.8700 - Val Recall: 0.8700 - Val F1: 0.8700 - LR: 0.0001
# Epoch 2730/10000 - Train Loss: 0.2864 - Val Precision: 0.8700 - Val Recall: 0.8700 - Val F1: 0.8700 - LR: 0.0001
# Epoch 2740/10000 - Train Loss: 0.2864 - Val Precision: 0.8700 - Val Recall: 0.8700 - Val F1: 0.8700 - LR: 0.0001
# Epoch 2750/10000 - Train Loss: 0.2864 - Val Precision: 0.8700 - Val Recall: 0.8700 - Val F1: 0.8700 - LR: 0.0001
# Epoch 2760/10000 - Train Loss: 0.2863 - Val Precision: 0.8700 - Val Recall: 0.8700 - Val F1: 0.8700 - LR: 0.0001
# Epoch 2770/10000 - Train Loss: 0.2863 - Val Precision: 0.8700 - Val Recall: 0.8700 - Val F1: 0.8700 - LR: 0.0001
# Epoch 2780/10000 - Train Loss: 0.2863 - Val Precision: 0.8700 - Val Recall: 0.8700 - Val F1: 0.8700 - LR: 0.0001
# Epoch 2790/10000 - Train Loss: 0.2863 - Val Precision: 0.8700 - Val Recall: 0.8700 - Val F1: 0.8700 - LR: 0.0001
# Epoch 2800/10000 - Train Loss: 0.2863 - Val Precision: 0.8700 - Val Recall: 0.8700 - Val F1: 0.8700 - LR: 0.0001
# Epoch 2810/10000 - Train Loss: 0.2863 - Val Precision: 0.8700 - Val Recall: 0.8700 - Val F1: 0.8700 - LR: 0.0001
# Epoch 2820/10000 - Train Loss: 0.2863 - Val Precision: 0.8700 - Val Recall: 0.8700 - Val F1: 0.8700 - LR: 0.0001
# Epoch 2830/10000 - Train Loss: 0.2863 - Val Precision: 0.8700 - Val Recall: 0.8700 - Val F1: 0.8700 - LR: 0.0001
# Epoch 2840/10000 - Train Loss: 0.2863 - Val Precision: 0.8700 - Val Recall: 0.8700 - Val F1: 0.8700 - LR: 0.0001
# Epoch 2850/10000 - Train Loss: 0.2862 - Val Precision: 0.8700 - Val Recall: 0.8700 - Val F1: 0.8700 - LR: 0.0001
# Epoch 2860/10000 - Train Loss: 0.2862 - Val Precision: 0.8700 - Val Recall: 0.8700 - Val F1: 0.8700 - LR: 0.0001
# Epoch 2870/10000 - Train Loss: 0.2862 - Val Precision: 0.8700 - Val Recall: 0.8700 - Val F1: 0.8700 - LR: 0.0001
# Epoch 2880/10000 - Train Loss: 0.2862 - Val Precision: 0.8700 - Val Recall: 0.8700 - Val F1: 0.8700 - LR: 0.0001
# Epoch 2890/10000 - Train Loss: 0.2862 - Val Precision: 0.8700 - Val Recall: 0.8700 - Val F1: 0.8700 - LR: 0.0001
# Epoch 2900/10000 - Train Loss: 0.2862 - Val Precision: 0.8700 - Val Recall: 0.8700 - Val F1: 0.8700 - LR: 0.0001
# Epoch 2910/10000 - Train Loss: 0.2862 - Val Precision: 0.8700 - Val Recall: 0.8700 - Val F1: 0.8700 - LR: 0.0001
# Epoch 2920/10000 - Train Loss: 0.2862 - Val Precision: 0.8700 - Val Recall: 0.8700 - Val F1: 0.8700 - LR: 0.0001
# Epoch 2930/10000 - Train Loss: 0.2861 - Val Precision: 0.8650 - Val Recall: 0.8650 - Val F1: 0.8650 - LR: 0.0001
# Epoch 2940/10000 - Train Loss: 0.2861 - Val Precision: 0.8650 - Val Recall: 0.8650 - Val F1: 0.8650 - LR: 0.0001
# Epoch 2950/10000 - Train Loss: 0.2861 - Val Precision: 0.8650 - Val Recall: 0.8650 - Val F1: 0.8650 - LR: 0.0001
# Epoch 2960/10000 - Train Loss: 0.2861 - Val Precision: 0.8650 - Val Recall: 0.8650 - Val F1: 0.8650 - LR: 0.0001
# Epoch 2970/10000 - Train Loss: 0.2861 - Val Precision: 0.8650 - Val Recall: 0.8650 - Val F1: 0.8650 - LR: 0.0001
# Epoch 2980/10000 - Train Loss: 0.2861 - Val Precision: 0.8650 - Val Recall: 0.8650 - Val F1: 0.8650 - LR: 0.0001
# Epoch 2990/10000 - Train Loss: 0.2861 - Val Precision: 0.8650 - Val Recall: 0.8650 - Val F1: 0.8650 - LR: 0.0001
# Epoch 3000/10000 - Train Loss: 0.2860 - Val Precision: 0.8650 - Val Recall: 0.8650 - Val F1: 0.8650 - LR: 0.0001
# Epoch 3010/10000 - Train Loss: 0.2860 - Val Precision: 0.8650 - Val Recall: 0.8650 - Val F1: 0.8650 - LR: 0.0001
# Epoch 3020/10000 - Train Loss: 0.2860 - Val Precision: 0.8650 - Val Recall: 0.8650 - Val F1: 0.8650 - LR: 0.0001
# Epoch 3030/10000 - Train Loss: 0.2860 - Val Precision: 0.8650 - Val Recall: 0.8650 - Val F1: 0.8650 - LR: 0.0001
# Epoch 3040/10000 - Train Loss: 0.2860 - Val Precision: 0.8650 - Val Recall: 0.8650 - Val F1: 0.8650 - LR: 0.0001
# Epoch 3050/10000 - Train Loss: 0.2860 - Val Precision: 0.8650 - Val Recall: 0.8650 - Val F1: 0.8650 - LR: 0.0001
# Epoch 3060/10000 - Train Loss: 0.2860 - Val Precision: 0.8650 - Val Recall: 0.8650 - Val F1: 0.8650 - LR: 0.0001
# Epoch 3070/10000 - Train Loss: 0.2860 - Val Precision: 0.8650 - Val Recall: 0.8650 - Val F1: 0.8650 - LR: 0.0001
# Epoch 3080/10000 - Train Loss: 0.2859 - Val Precision: 0.8650 - Val Recall: 0.8650 - Val F1: 0.8650 - LR: 0.0001
# Epoch 3090/10000 - Train Loss: 0.2859 - Val Precision: 0.8650 - Val Recall: 0.8650 - Val F1: 0.8650 - LR: 0.0001
# Epoch 3100/10000 - Train Loss: 0.2859 - Val Precision: 0.8650 - Val Recall: 0.8650 - Val F1: 0.8650 - LR: 0.0001
# Epoch 3110/10000 - Train Loss: 0.2859 - Val Precision: 0.8650 - Val Recall: 0.8650 - Val F1: 0.8650 - LR: 0.0001
# Epoch 3120/10000 - Train Loss: 0.2859 - Val Precision: 0.8650 - Val Recall: 0.8650 - Val F1: 0.8650 - LR: 0.0001
# Epoch 3130/10000 - Train Loss: 0.2859 - Val Precision: 0.8650 - Val Recall: 0.8650 - Val F1: 0.8650 - LR: 0.0001
# Epoch 3140/10000 - Train Loss: 0.2859 - Val Precision: 0.8650 - Val Recall: 0.8650 - Val F1: 0.8650 - LR: 0.0001
# Epoch 3150/10000 - Train Loss: 0.2858 - Val Precision: 0.8650 - Val Recall: 0.8650 - Val F1: 0.8650 - LR: 0.0001
# Epoch 3160/10000 - Train Loss: 0.2858 - Val Precision: 0.8650 - Val Recall: 0.8650 - Val F1: 0.8650 - LR: 0.0001
# Epoch 3170/10000 - Train Loss: 0.2858 - Val Precision: 0.8650 - Val Recall: 0.8650 - Val F1: 0.8650 - LR: 0.0001
# Epoch 3180/10000 - Train Loss: 0.2858 - Val Precision: 0.8650 - Val Recall: 0.8650 - Val F1: 0.8650 - LR: 0.0001
# Epoch 3190/10000 - Train Loss: 0.2858 - Val Precision: 0.8650 - Val Recall: 0.8650 - Val F1: 0.8650 - LR: 0.0001
# Epoch 3200/10000 - Train Loss: 0.2858 - Val Precision: 0.8650 - Val Recall: 0.8650 - Val F1: 0.8650 - LR: 1e-05
# Epoch 3210/10000 - Train Loss: 0.2858 - Val Precision: 0.8650 - Val Recall: 0.8650 - Val F1: 0.8650 - LR: 1e-05
# Epoch 3220/10000 - Train Loss: 0.2858 - Val Precision: 0.8650 - Val Recall: 0.8650 - Val F1: 0.8650 - LR: 1e-05
# Epoch 3230/10000 - Train Loss: 0.2858 - Val Precision: 0.8650 - Val Recall: 0.8650 - Val F1: 0.8650 - LR: 1e-05
# Epoch 3240/10000 - Train Loss: 0.2858 - Val Precision: 0.8650 - Val Recall: 0.8650 - Val F1: 0.8650 - LR: 1e-05
# Epoch 3250/10000 - Train Loss: 0.2858 - Val Precision: 0.8650 - Val Recall: 0.8650 - Val F1: 0.8650 - LR: 1e-05
# Epoch 3260/10000 - Train Loss: 0.2858 - Val Precision: 0.8650 - Val Recall: 0.8650 - Val F1: 0.8650 - LR: 1e-05
# Epoch 3270/10000 - Train Loss: 0.2858 - Val Precision: 0.8650 - Val Recall: 0.8650 - Val F1: 0.8650 - LR: 1e-05
# Epoch 3280/10000 - Train Loss: 0.2858 - Val Precision: 0.8650 - Val Recall: 0.8650 - Val F1: 0.8650 - LR: 1e-05
# Epoch 3290/10000 - Train Loss: 0.2858 - Val Precision: 0.8650 - Val Recall: 0.8650 - Val F1: 0.8650 - LR: 1e-05
# Epoch 3300/10000 - Train Loss: 0.2857 - Val Precision: 0.8650 - Val Recall: 0.8650 - Val F1: 0.8650 - LR: 1e-05
# Epoch 3310/10000 - Train Loss: 0.2857 - Val Precision: 0.8650 - Val Recall: 0.8650 - Val F1: 0.8650 - LR: 1e-05
# Epoch 3320/10000 - Train Loss: 0.2857 - Val Precision: 0.8650 - Val Recall: 0.8650 - Val F1: 0.8650 - LR: 1e-05
# Epoch 3330/10000 - Train Loss: 0.2857 - Val Precision: 0.8650 - Val Recall: 0.8650 - Val F1: 0.8650 - LR: 1e-05
# Epoch 3340/10000 - Train Loss: 0.2857 - Val Precision: 0.8650 - Val Recall: 0.8650 - Val F1: 0.8650 - LR: 1e-05
# Epoch 3350/10000 - Train Loss: 0.2857 - Val Precision: 0.8650 - Val Recall: 0.8650 - Val F1: 0.8650 - LR: 1e-05
# Epoch 3360/10000 - Train Loss: 0.2857 - Val Precision: 0.8650 - Val Recall: 0.8650 - Val F1: 0.8650 - LR: 1e-05
# Epoch 3370/10000 - Train Loss: 0.2857 - Val Precision: 0.8650 - Val Recall: 0.8650 - Val F1: 0.8650 - LR: 1e-05
# Epoch 3380/10000 - Train Loss: 0.2857 - Val Precision: 0.8650 - Val Recall: 0.8650 - Val F1: 0.8650 - LR: 1e-05
# Epoch 3390/10000 - Train Loss: 0.2857 - Val Precision: 0.8650 - Val Recall: 0.8650 - Val F1: 0.8650 - LR: 1e-05
# Epoch 3400/10000 - Train Loss: 0.2857 - Val Precision: 0.8650 - Val Recall: 0.8650 - Val F1: 0.8650 - LR: 1e-05
# Epoch 3410/10000 - Train Loss: 0.2857 - Val Precision: 0.8650 - Val Recall: 0.8650 - Val F1: 0.8650 - LR: 1e-05
# Epoch 3420/10000 - Train Loss: 0.2857 - Val Precision: 0.8650 - Val Recall: 0.8650 - Val F1: 0.8650 - LR: 1e-05
# Epoch 3430/10000 - Train Loss: 0.2857 - Val Precision: 0.8650 - Val Recall: 0.8650 - Val F1: 0.8650 - LR: 1e-05
# Epoch 3440/10000 - Train Loss: 0.2857 - Val Precision: 0.8650 - Val Recall: 0.8650 - Val F1: 0.8650 - LR: 1e-05
# Epoch 3450/10000 - Train Loss: 0.2857 - Val Precision: 0.8650 - Val Recall: 0.8650 - Val F1: 0.8650 - LR: 1e-05
# Epoch 3460/10000 - Train Loss: 0.2857 - Val Precision: 0.8650 - Val Recall: 0.8650 - Val F1: 0.8650 - LR: 1e-05
# Epoch 3470/10000 - Train Loss: 0.2857 - Val Precision: 0.8650 - Val Recall: 0.8650 - Val F1: 0.8650 - LR: 1e-05
# Epoch 3480/10000 - Train Loss: 0.2857 - Val Precision: 0.8650 - Val Recall: 0.8650 - Val F1: 0.8650 - LR: 1e-05
# Epoch 3490/10000 - Train Loss: 0.2857 - Val Precision: 0.8650 - Val Recall: 0.8650 - Val F1: 0.8650 - LR: 1e-05
# Epoch 3500/10000 - Train Loss: 0.2857 - Val Precision: 0.8650 - Val Recall: 0.8650 - Val F1: 0.8650 - LR: 1e-05
# Epoch 3510/10000 - Train Loss: 0.2857 - Val Precision: 0.8650 - Val Recall: 0.8650 - Val F1: 0.8650 - LR: 1e-05
# Epoch 3520/10000 - Train Loss: 0.2857 - Val Precision: 0.8650 - Val Recall: 0.8650 - Val F1: 0.8650 - LR: 1e-05
# Epoch 3530/10000 - Train Loss: 0.2857 - Val Precision: 0.8650 - Val Recall: 0.8650 - Val F1: 0.8650 - LR: 1e-05
# Epoch 3540/10000 - Train Loss: 0.2857 - Val Precision: 0.8650 - Val Recall: 0.8650 - Val F1: 0.8650 - LR: 1e-05
# Epoch 3550/10000 - Train Loss: 0.2857 - Val Precision: 0.8650 - Val Recall: 0.8650 - Val F1: 0.8650 - LR: 1e-05
# Epoch 3560/10000 - Train Loss: 0.2857 - Val Precision: 0.8650 - Val Recall: 0.8650 - Val F1: 0.8650 - LR: 1e-05
# Epoch 3570/10000 - Train Loss: 0.2857 - Val Precision: 0.8650 - Val Recall: 0.8650 - Val F1: 0.8650 - LR: 1e-05
# Epoch 3580/10000 - Train Loss: 0.2857 - Val Precision: 0.8650 - Val Recall: 0.8650 - Val F1: 0.8650 - LR: 1e-05
# Epoch 3590/10000 - Train Loss: 0.2857 - Val Precision: 0.8650 - Val Recall: 0.8650 - Val F1: 0.8650 - LR: 1e-05
# Epoch 3600/10000 - Train Loss: 0.2857 - Val Precision: 0.8650 - Val Recall: 0.8650 - Val F1: 0.8650 - LR: 1e-05
# Epoch 3610/10000 - Train Loss: 0.2857 - Val Precision: 0.8650 - Val Recall: 0.8650 - Val F1: 0.8650 - LR: 1e-05
# Epoch 3620/10000 - Train Loss: 0.2857 - Val Precision: 0.8650 - Val Recall: 0.8650 - Val F1: 0.8650 - LR: 1e-05
# Epoch 3630/10000 - Train Loss: 0.2857 - Val Precision: 0.8650 - Val Recall: 0.8650 - Val F1: 0.8650 - LR: 1e-05
# Epoch 3640/10000 - Train Loss: 0.2857 - Val Precision: 0.8650 - Val Recall: 0.8650 - Val F1: 0.8650 - LR: 1e-05
# Epoch 3650/10000 - Train Loss: 0.2857 - Val Precision: 0.8650 - Val Recall: 0.8650 - Val F1: 0.8650 - LR: 1e-05
# Epoch 3660/10000 - Train Loss: 0.2857 - Val Precision: 0.8650 - Val Recall: 0.8650 - Val F1: 0.8650 - LR: 1e-05
# Epoch 3670/10000 - Train Loss: 0.2857 - Val Precision: 0.8650 - Val Recall: 0.8650 - Val F1: 0.8650 - LR: 1e-05
# Epoch 3680/10000 - Train Loss: 0.2857 - Val Precision: 0.8650 - Val Recall: 0.8650 - Val F1: 0.8650 - LR: 1e-05
# Epoch 3690/10000 - Train Loss: 0.2857 - Val Precision: 0.8650 - Val Recall: 0.8650 - Val F1: 0.8650 - LR: 1e-05
# Epoch 3700/10000 - Train Loss: 0.2857 - Val Precision: 0.8650 - Val Recall: 0.8650 - Val F1: 0.8650 - LR: 1e-05
# Epoch 3710/10000 - Train Loss: 0.2857 - Val Precision: 0.8650 - Val Recall: 0.8650 - Val F1: 0.8650 - LR: 1.0000000000000002e-06
# [VAL] Prec=0.8900, Rec=0.8900, F1=0.8900

# %% [markdown]
# ## Question 2.3 Node-Type Aware GCN
#
# In this task, **design and implement** a node-type aware 2-layer GCN model that explicitly accounts for two distinct node types and performs binary node classification. Your design should adhere to the following requirements:
#
# - Consider two types of nodes without using padding.
# - Limit your model to **two layers**, as in the naive solution.
# - You may either use the provided `GCNLayer` and `GraphNeuralNetwork` classes or implement your own classes. However, the final model architecture must be implemented within the `HeteroGCN` class.
# - While you are allowed to introduce additional learnable parameters, your approach must **explicitly** account for different node types rather than merely increasing the number of learnable parameters.
# - Determine the optimal hyperparameters for your model, such as hidden dimensions, learning rate, scheduler patience, etc. These hyperparameters do not need to match those of the naive model, as each design has its own optimal configuration.
# - Your model must achieve superior **validation F1 score** compared to the naive approach.
# - You may use different versions of adjacency matrices in your implementation:
#   - Unmodified adjacency matrices, i.e., `A_train`.
#   - Self-looped adjacency matrices, i.e., `A_train_self_loops`.
#   - Normalized adjacency matrices, i.e., `A_train_normalized`.
#
# Please see the Coursework Description PDF Question 2.3 for more details

# %%
# ####################################################
# MODIFY THE CODE BELOW 
# ####################################################

class HeteroGCN(nn.Module):
    def __init__(self, input_dim1, input_dim2, hidden_dim, output_dim, dropout=0.3):
        """
        Args:
            input_dim1 (int): Input feature size for Type 1 nodes.
            input_dim2 (int): Input feature size for Type 2 nodes.
            hidden_dim (int): Hidden layer size.
            output_dim (int): Output size (usually 1 for binary classification).
            dropout (float): Dropout rate.
        """
        super(HeteroGCN, self).__init__()

        # Separate feature transformations for Type 1 and Type 2 nodes
        self.gcn1_type1 = nn.Linear(input_dim1, hidden_dim)
        self.gcn1_type2 = nn.Linear(input_dim2, hidden_dim)

        # Second GCN layers
        self.gcn2 = nn.Linear(hidden_dim, output_dim)

        # Dropout layer for regularization
        self.dropout = nn.Dropout(dropout)

    def forward(self, A, X1, X2, mapping):
        """
        Forward pass for HeteroGCN.

        Args:
            A (torch.FloatTensor): Adjacency matrix (N x N).
            X1 (torch.FloatTensor): Feature matrix for Type 1 nodes (N1, d1).
            X2 (torch.FloatTensor): Feature matrix for Type 2 nodes (N2, d2).
            mapping (dict): Mapping of global node index -> type and index in feature matrix.

        Returns:
            torch.Tensor: Predicted node labels.
        """

        N = A.shape[0]  # Number of total nodes
        H = torch.zeros((N, self.gcn1_type1.out_features), device=A.device)

        # Process each node according to its type
        for i in range(N):
            node_info = mapping[i]
            node_type = node_info["node_type"]
            feat_index = node_info["feat_index"]

            if node_type == "type1" and len(X1) > 0:
                H[i] = F.relu(self.gcn1_type1(X1[feat_index]))
            elif node_type == "type2" and len(X2) > 0:
                H[i] = F.relu(self.gcn1_type2(X2[feat_index]))

        # Apply adjacency matrix aggregation (Graph Convolution)
        H = torch.matmul(A, H)

        # Apply second GCN layer
        H = self.gcn2(H)
        
        # Apply dropout and sigmoid activation for classification
        H = self.dropout(H)
        output = torch.sigmoid(H)

        return output

# ####################################################
# END OF MODIFICATION
# ####################################################

# %%
set_seed(SEED)

# Convert labels to float if using BCE with sigmoid
y_train = y_train.float()  # shape (N,)
y_val   = y_val.float()

# ####################################################
# MODIFY THE CODE BELOW 
# ####################################################
# Build the HeteroGCN model
hetero_gcn = HeteroGCN(
    input_dim1=X1_train.shape[1],  # Feature dimension for Type 1 nodes
    input_dim2=X2_train.shape[1],  # Feature dimension for Type 2 nodes
    hidden_dim=16,  # Hidden layer size
    output_dim=1,  # Binary classification (1 output per node)
    dropout=0.3  # Regularization
)


# Train
loss_history, _ = train_model(
    hetero_gcn, 
    y_train, 
    val_model_inputs={"A": A_val, "X1": X1_val, "X2": X2_val, "mapping": mapping_val},  # Pass validation inputs
    y_val=y_val,
    num_epochs=50,  # Number of training epochs
    lr=0.001,  # Learning rate
    validate_every=5,  # Validate every 5 epochs
    patience=7,  # Early stopping patience
    A=A_train, X1=X1_train, X2=X2_train, mapping=mapping_train  # Training inputs
)


# ####################################################
# END OF MODIFICATION
# ####################################################

# Test on validation data
val_prec, val_rec, val_f1, _ = evaluate_model(
    hetero_gcn,
    y_val,
    A=A_val, 
    X1=X1_val, 
    X2=X2_val, 
    mapping=mapping_val
)
print(f"[VAL] Prec={val_prec:.4f}, Rec={val_rec:.4f}, F1={val_f1:.4f}")

val_precs["Hetero GCN"] = val_prec
val_recs["Hetero GCN"] = val_rec
val_f1s["Hetero GCN"] = val_f1

# Plot loss
plot_loss(loss_history, title="Hetero GNN Approach Training Loss")
# Out:
# Epoch 5/50 - Train Loss: 5.8053 - Val Precision: 0.5000 - Val Recall: 0.5000 - Val F1: 0.5000 - LR: 0.001
# Epoch 10/50 - Train Loss: 4.5236 - Val Precision: 0.5050 - Val Recall: 0.5050 - Val F1: 0.5050 - LR: 0.001
# Epoch 15/50 - Train Loss: 3.3518 - Val Precision: 0.5100 - Val Recall: 0.5100 - Val F1: 0.5100 - LR: 0.001
# Epoch 20/50 - Train Loss: 2.1363 - Val Precision: 0.5100 - Val Recall: 0.5100 - Val F1: 0.5100 - LR: 0.001
# Epoch 25/50 - Train Loss: 0.9606 - Val Precision: 0.4550 - Val Recall: 0.4550 - Val F1: 0.4550 - LR: 0.001
# Epoch 30/50 - Train Loss: 0.7978 - Val Precision: 0.4900 - Val Recall: 0.4900 - Val F1: 0.4900 - LR: 0.001
# Epoch 35/50 - Train Loss: 0.8655 - Val Precision: 0.4950 - Val Recall: 0.4950 - Val F1: 0.4950 - LR: 0.001
# Epoch 40/50 - Train Loss: 0.7345 - Val Precision: 0.4650 - Val Recall: 0.4650 - Val F1: 0.4650 - LR: 0.001
# Epoch 45/50 - Train Loss: 0.7744 - Val Precision: 0.4050 - Val Recall: 0.4050 - Val F1: 0.4050 - LR: 0.001
# Epoch 50/50 - Train Loss: 0.7264 - Val Precision: 0.4700 - Val Recall: 0.4700 - Val F1: 0.4700 - LR: 0.001
# [VAL] Prec=0.5100, Rec=0.5100, F1=0.5100

# %% [markdown]
# ## Question 2.4 Exploring Attention
# In this question, you will explore the attention-based aggregation mechanism in GNNs. Attention-based aggregation is explained in [Lecture 3.5](https://www.youtube.com/watch?v=zRmzVkidkqA&list=PLug43ldmRSo14Y_vt7S6vanPGh-JpHR7T&index=14).
#
# - Implement an attention-based aggregation mechanism for binary node classification using GCNs.
# - Limit your model to **two layers**, as in Question 2.2 and Question 2.3
# - Base your implementation on the naive padding approach introduced in Question 2.2
# - **Do not** implement a node-type aware special design as in Question 2.3
# - Your implementation must achieve a better **validation F1 score** compared to the naive GCN in Question 2.2
# - Determine the optimal hyperparameters for your model, such as hidden dimensions, learning rate, scheduler patience, etc. These hyperparameters do not need to match those of the previous models, as each design has its own optimal configuration. Explain your hyperparameter tuning process **in detail** in your report.

# %%
# ####################################################
# MODIFY THE CODE BELOW 
# ####################################################

class GraphAttentionLayer(nn.Module):
    def __init__(self, input_dim, out_dim, nonlinear = False):
        super(GraphAttentionLayer, self).__init__()
        self.nonlinear = nonlinear

        self.W = nn.Parameter(torch.randn(input_dim, out_dim) * torch.sqrt(torch.tensor(2.0) / (out_dim + input_dim)))

        self.a = nn.Parameter(torch.randn(2 * out_dim))
        self.beta = nn.Parameter(torch.zeros(out_dim))

    def forward(self, A_hat, X):
        X = torch.matmul(X, self.W) + self.beta

        X1 = torch.matmul(X, self.a[:X.shape[1]])  
        X2 = torch.matmul(X, self.a[X.shape[1]:])  
        S = X1.unsqueeze(1) + X2.T
        S = F.leaky_relu(S)

        S_masked = S.masked_fill(A_hat == 0, -1e9)
        attention_weights = F.softmax(S_masked, dim=0)
        X = torch.matmul(attention_weights, X)

        if self.nonlinear:
            X = F.elu(X)

        return X



class GraphAttentionNetwork(nn.Module):
    def __init__(self, input_dim, hidden_dim, out_dim, dr = 0.1, num_layers = 2):
        super(GraphAttentionNetwork, self).__init__()


        self.dr = dr

        self.layers = nn.ModuleList()
        self.layers.append(
            GraphAttentionLayer(input_dim, hidden_dim, nonlinear = True)
        )

        for i in range(num_layers - 2):
            self.layers.append(hidden_dim, hidden_dim, nonlinear = True)

        self.layers.append(
            GraphAttentionLayer(hidden_dim, out_dim, nonlinear = False)
        )

    def forward(self, A, X):
        for i, layer in enumerate(self.layers):
            X = layer(A, X)


            if i < len(self.layers) - 1: 
                X = F.dropout(X, p=self.dr, training=self.training)
        output = torch.sigmoid(X)

        return output
        
# ####################################################
# END OF MODIFICATION
# ####################################################

# %%
set_seed(SEED)

# Naively pad
X_train, d_max_train = pad_features(A_train, X1_train, X2_train, mapping_train)
X_val,   d_max_val   = pad_features(A_val,   X1_val,   X2_val,   mapping_val)

print("Train adjacency:", A_train.shape)
print("Train features after padding:", X_train.shape, "with d_max =", d_max_train)
print("Val adjacency:", A_val.shape)
print("Val features after padding:", X_val.shape, "with d_max =", d_max_val)

# Convert labels to float if using BCE with sigmoid
y_train = y_train.float()  # shape (N,)
y_val   = y_val.float()


# ####################################################
# MODIFY THE CODE BELOW 
# ####################################################

# Build the model
attn_gnn = GraphAttentionNetwork(X_train.shape[1], 10, 1)

# Train
loss_history, _ = train_model(
    attn_gnn,
    y_train,
    val_model_inputs={"A": A_val_self_loops, "X": X_val},  # Pass validation inputs
    y_val=y_val,
    A=A_train_self_loops,
    X=X_train,
    num_epochs=10000,  # Number of training epochs
    lr=0.005,  # Learning rate
    validate_every=5,
    patience=10
)

# ####################################################
# END OF MODIFICATION
# ####################################################

# Test on validation data
val_prec, val_rec, val_f1, _ = evaluate_model(attn_gnn, y_val, A=A_val_normalized, X=X_val)
print(f"[VAL] Prec={val_prec:.4f}, Rec={val_rec:.4f}, F1={val_f1:.4f}")

val_precs["Naive GAT"] = val_prec
val_recs["Naive GAT"] = val_rec
val_f1s["Naive GAT"] = val_f1

# Plot loss
plot_loss(loss_history, title="GAT Naive Approach Training Loss")
# Out:
# Train adjacency: torch.Size([500, 500])
# Train features after padding: torch.Size([500, 30]) with d_max = 30
# Val adjacency: torch.Size([200, 200])
# Val features after padding: torch.Size([200, 30]) with d_max = 30
# Epoch 5/10000 - Train Loss: 0.6944 - Val Precision: 0.5000 - Val Recall: 0.5000 - Val F1: 0.5000 - LR: 0.005
# Epoch 10/10000 - Train Loss: 0.7056 - Val Precision: 0.5000 - Val Recall: 0.5000 - Val F1: 0.5000 - LR: 0.005
# Epoch 15/10000 - Train Loss: 0.6917 - Val Precision: 0.5000 - Val Recall: 0.5000 - Val F1: 0.5000 - LR: 0.005
# Epoch 20/10000 - Train Loss: 0.6927 - Val Precision: 0.5000 - Val Recall: 0.5000 - Val F1: 0.5000 - LR: 0.005
# Epoch 25/10000 - Train Loss: 0.6901 - Val Precision: 0.4950 - Val Recall: 0.4950 - Val F1: 0.4950 - LR: 0.005
# Epoch 30/10000 - Train Loss: 0.6897 - Val Precision: 0.4900 - Val Recall: 0.4900 - Val F1: 0.4900 - LR: 0.005
# Epoch 35/10000 - Train Loss: 0.6811 - Val Precision: 0.4900 - Val Recall: 0.4900 - Val F1: 0.4900 - LR: 0.005
# Epoch 40/10000 - Train Loss: 0.6795 - Val Precision: 0.5450 - Val Recall: 0.5450 - Val F1: 0.5450 - LR: 0.005
# Epoch 45/10000 - Train Loss: 0.6747 - Val Precision: 0.5600 - Val Recall: 0.5600 - Val F1: 0.5600 - LR: 0.005
# Epoch 50/10000 - Train Loss: 0.6663 - Val Precision: 0.5000 - Val Recall: 0.5000 - Val F1: 0.5000 - LR: 0.005
# Epoch 55/10000 - Train Loss: 0.6562 - Val Precision: 0.5050 - Val Recall: 0.5050 - Val F1: 0.5050 - LR: 0.005
# Epoch 60/10000 - Train Loss: 0.6477 - Val Precision: 0.5500 - Val Recall: 0.5500 - Val F1: 0.5500 - LR: 0.005
# Epoch 65/10000 - Train Loss: 0.6408 - Val Precision: 0.5150 - Val Recall: 0.5150 - Val F1: 0.5150 - LR: 0.005
# Epoch 70/10000 - Train Loss: 0.6296 - Val Precision: 0.5400 - Val Recall: 0.5400 - Val F1: 0.5400 - LR: 0.005
# Epoch 75/10000 - Train Loss: 0.6226 - Val Precision: 0.5400 - Val Recall: 0.5400 - Val F1: 0.5400 - LR: 0.005
# Epoch 80/10000 - Train Loss: 0.6184 - Val Precision: 0.5400 - Val Recall: 0.5400 - Val F1: 0.5400 - LR: 0.005
# Epoch 85/10000 - Train Loss: 0.6115 - Val Precision: 0.5350 - Val Recall: 0.5350 - Val F1: 0.5350 - LR: 0.005
# Epoch 90/10000 - Train Loss: 0.6071 - Val Precision: 0.5350 - Val Recall: 0.5350 - Val F1: 0.5350 - LR: 0.005
# Epoch 95/10000 - Train Loss: 0.5995 - Val Precision: 0.5350 - Val Recall: 0.5350 - Val F1: 0.5350 - LR: 0.005
# Epoch 100/10000 - Train Loss: 0.5963 - Val Precision: 0.5150 - Val Recall: 0.5150 - Val F1: 0.5150 - LR: 0.0005
# Epoch 105/10000 - Train Loss: 0.5956 - Val Precision: 0.5150 - Val Recall: 0.5150 - Val F1: 0.5150 - LR: 0.0005
# Epoch 110/10000 - Train Loss: 0.5953 - Val Precision: 0.5250 - Val Recall: 0.5250 - Val F1: 0.5250 - LR: 0.0005
# Epoch 115/10000 - Train Loss: 0.5950 - Val Precision: 0.5300 - Val Recall: 0.5300 - Val F1: 0.5300 - LR: 0.0005
# Epoch 120/10000 - Train Loss: 0.5946 - Val Precision: 0.5300 - Val Recall: 0.5300 - Val F1: 0.5300 - LR: 0.0005
# Epoch 125/10000 - Train Loss: 0.5939 - Val Precision: 0.5150 - Val Recall: 0.5150 - Val F1: 0.5150 - LR: 0.0005
# Epoch 130/10000 - Train Loss: 0.5929 - Val Precision: 0.5100 - Val Recall: 0.5100 - Val F1: 0.5100 - LR: 0.0005
# Epoch 135/10000 - Train Loss: 0.5927 - Val Precision: 0.5100 - Val Recall: 0.5100 - Val F1: 0.5100 - LR: 0.0005
# Epoch 140/10000 - Train Loss: 0.5935 - Val Precision: 0.5150 - Val Recall: 0.5150 - Val F1: 0.5150 - LR: 0.0005
# Epoch 145/10000 - Train Loss: 0.5922 - Val Precision: 0.5150 - Val Recall: 0.5150 - Val F1: 0.5150 - LR: 0.0005
# Epoch 150/10000 - Train Loss: 0.5921 - Val Precision: 0.5150 - Val Recall: 0.5150 - Val F1: 0.5150 - LR: 0.0005
# Epoch 155/10000 - Train Loss: 0.5917 - Val Precision: 0.5100 - Val Recall: 0.5100 - Val F1: 0.5100 - LR: 5e-05
# Epoch 160/10000 - Train Loss: 0.5917 - Val Precision: 0.5100 - Val Recall: 0.5100 - Val F1: 0.5100 - LR: 5e-05
# Epoch 165/10000 - Train Loss: 0.5914 - Val Precision: 0.5100 - Val Recall: 0.5100 - Val F1: 0.5100 - LR: 5e-05
# Epoch 170/10000 - Train Loss: 0.5913 - Val Precision: 0.5100 - Val Recall: 0.5100 - Val F1: 0.5100 - LR: 5e-05
# Epoch 175/10000 - Train Loss: 0.5909 - Val Precision: 0.5100 - Val Recall: 0.5100 - Val F1: 0.5100 - LR: 5e-05
# Epoch 180/10000 - Train Loss: 0.5899 - Val Precision: 0.5100 - Val Recall: 0.5100 - Val F1: 0.5100 - LR: 5e-05
# Epoch 185/10000 - Train Loss: 0.5916 - Val Precision: 0.5100 - Val Recall: 0.5100 - Val F1: 0.5100 - LR: 5e-05
# Epoch 190/10000 - Train Loss: 0.5913 - Val Precision: 0.5100 - Val Recall: 0.5100 - Val F1: 0.5100 - LR: 5e-05
# Epoch 195/10000 - Train Loss: 0.5913 - Val Precision: 0.5100 - Val Recall: 0.5100 - Val F1: 0.5100 - LR: 5e-05
# Epoch 200/10000 - Train Loss: 0.5912 - Val Precision: 0.5150 - Val Recall: 0.5150 - Val F1: 0.5150 - LR: 5e-05
# Epoch 205/10000 - Train Loss: 0.5906 - Val Precision: 0.5150 - Val Recall: 0.5150 - Val F1: 0.5150 - LR: 5e-05
# Epoch 210/10000 - Train Loss: 0.5914 - Val Precision: 0.5150 - Val Recall: 0.5150 - Val F1: 0.5150 - LR: 5e-06
# [VAL] Prec=0.5600, Rec=0.5600, F1=0.5600

# %% [markdown]
# ## Question 2.5 Discussion
#
# In your report, include the bar plot comparing the **precision, recall, and F1 scores** of the three models, generated using the following function call. Explain your results in your report.

# %%
plot_results(val_precs, val_recs, val_f1s)
